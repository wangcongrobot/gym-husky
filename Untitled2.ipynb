# %%
pip install torch pandas
# Out:
# Requirement already satisfied: torch in /home/cong/workspace/rllib/lib/python3.7/site-packages (1.3.0)
# Requirement already satisfied: pandas in /home/cong/workspace/rllib/lib/python3.7/site-packages (0.25.2)
# Requirement already satisfied: numpy in /home/cong/workspace/rllib/lib/python3.7/site-packages (from torch) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/cong/workspace/rllib/lib/python3.7/site-packages (from pandas) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /home/cong/workspace/rllib/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in /home/cong/workspace/rllib/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
Implementation of PPO
ref: Schulman, John, et al. "Proximal policy optimization algorithms." arXiv preprint arXiv:1707.06347 (2017).
ref: https://github.com/Jiankai-Sun/Proximal-Policy-Optimization-in-Pytorch/blob/master/ppo.py
ref: https://github.com/openai/baselines/tree/master/baselines/ppo2
NOTICE:
    `Tensor2` means 2D-Tensor (num_samples, num_dims) 
"""

import gym
import torch
import torch.nn as nn
import torch.optim as opt
from torch import Tensor
from torch.autograd import Variable
from collections import namedtuple
from itertools import count
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
from os.path import join as joindir
from os import makedirs as mkdir
import pandas as pd
import numpy as np
import argparse
import datetime
import math


Transition = namedtuple('Transition', ('state', 'value', 'action', 'logproba', 'mask', 'next_state', 'reward'))
EPS = 1e-10
__file__ = '/home/cong/ray_results/'
RESULT_DIR = joindir('../result', '.'.join(__file__.split('.')[:-1]))
mkdir(RESULT_DIR, exist_ok=True)


class args(object):
    env_name = 'Hopper-v2'
    seed = 1234
    num_episode = 2000
    batch_size = 2048
    max_step_per_round = 2000
    gamma = 0.995
    lamda = 0.97
    log_num_episode = 1
    num_epoch = 10
    minibatch_size = 256
    clip = 0.2
    loss_coeff_value = 0.5
    loss_coeff_entropy = 0.01
    lr = 3e-4
    num_parallel_run = 5
    # tricks
    schedule_adam = 'linear'
    schedule_clip = 'linear'
    layer_norm = True
    state_norm = True
    advantage_norm = True
    lossvalue_norm = True


class RunningStat(object):
    def __init__(self, shape):
        self._n = 0
        self._M = np.zeros(shape)
        self._S = np.zeros(shape)

    def push(self, x):
        x = np.asarray(x)
        assert x.shape == self._M.shape
        self._n += 1
        if self._n == 1:
            self._M[...] = x
        else:
            oldM = self._M.copy()
            self._M[...] = oldM + (x - oldM) / self._n
            self._S[...] = self._S + (x - oldM) * (x - self._M)

    @property
    def n(self):
        return self._n

    @property
    def mean(self):
        return self._M

    @property
    def var(self):
        return self._S / (self._n - 1) if self._n > 1 else np.square(self._M)

    @property
    def std(self):
        return np.sqrt(self.var)

    @property
    def shape(self):
        return self._M.shape


class ZFilter:
    """
    y = (x-mean)/std
    using running estimates of mean,std
    """

    def __init__(self, shape, demean=True, destd=True, clip=10.0):
        self.demean = demean
        self.destd = destd
        self.clip = clip

        self.rs = RunningStat(shape)

    def __call__(self, x, update=True):
        if update: self.rs.push(x)
        if self.demean:
            x = x - self.rs.mean
        if self.destd:
            x = x / (self.rs.std + 1e-8)
        if self.clip:
            x = np.clip(x, -self.clip, self.clip)
        return x

    def output_shape(self, input_space):
        return input_space.shape


class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_outputs, layer_norm=True):
        super(ActorCritic, self).__init__()
        
        self.actor_fc1 = nn.Linear(num_inputs, 64)
        self.actor_fc2 = nn.Linear(64, 64)
        self.actor_fc3 = nn.Linear(64, num_outputs)
        self.actor_logstd = nn.Parameter(torch.zeros(1, num_outputs))

        self.critic_fc1 = nn.Linear(num_inputs, 64)
        self.critic_fc2 = nn.Linear(64, 64)
        self.critic_fc3 = nn.Linear(64, 1)

        if layer_norm:
            self.layer_norm(self.actor_fc1, std=1.0)
            self.layer_norm(self.actor_fc2, std=1.0)
            self.layer_norm(self.actor_fc3, std=0.01)

            self.layer_norm(self.critic_fc1, std=1.0)
            self.layer_norm(self.critic_fc2, std=1.0)
            self.layer_norm(self.critic_fc3, std=1.0)

    @staticmethod
    def layer_norm(layer, std=1.0, bias_const=0.0):
        torch.nn.init.orthogonal_(layer.weight, std)
        torch.nn.init.constant_(layer.bias, bias_const)

    def forward(self, states):
        """
        run policy network (actor) as well as value network (critic)
        :param states: a Tensor2 represents states
        :return: 3 Tensor2
        """
        action_mean, action_logstd = self._forward_actor(states)
        critic_value = self._forward_critic(states)
        return action_mean, action_logstd, critic_value

    def _forward_actor(self, states):
        x = torch.tanh(self.actor_fc1(states))
        x = torch.tanh(self.actor_fc2(x))
        action_mean = self.actor_fc3(x)
        action_logstd = self.actor_logstd.expand_as(action_mean)
        return action_mean, action_logstd

    def _forward_critic(self, states):
        x = torch.tanh(self.critic_fc1(states))
        x = torch.tanh(self.critic_fc2(x))
        critic_value = self.critic_fc3(x)
        return critic_value

    def select_action(self, action_mean, action_logstd, return_logproba=True):
        """
        given mean and std, sample an action from normal(mean, std)
        also returns probability of the given chosen
        """
        action_std = torch.exp(action_logstd)
        action = torch.normal(action_mean, action_std)
        if return_logproba:
            logproba = self._normal_logproba(action, action_mean, action_logstd, action_std)
        return action, logproba

    @staticmethod
    def _normal_logproba(x, mean, logstd, std=None):
        if std is None:
            std = torch.exp(logstd)

        std_sq = std.pow(2)
        logproba = - 0.5 * math.log(2 * math.pi) - logstd - (x - mean).pow(2) / (2 * std_sq)
        return logproba.sum(1)

    def get_logproba(self, states, actions):
        """
        return probability of chosen the given actions under corresponding states of current network
        :param states: Tensor
        :param actions: Tensor
        """
        action_mean, action_logstd = self._forward_actor(states)
        logproba = self._normal_logproba(actions, action_mean, action_logstd)
        return logproba

    
class Memory(object):
    def __init__(self):
        self.memory = []

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self):
        return Transition(*zip(*self.memory))

    def __len__(self):
        return len(self.memory)

def ppo(args):
    env = gym.make(args.env_name)
    num_inputs = env.observation_space.shape[0]
    num_actions = env.action_space.shape[0]

    env.seed(args.seed)
    torch.manual_seed(args.seed)

    network = ActorCritic(num_inputs, num_actions, layer_norm=args.layer_norm)
    optimizer = opt.Adam(network.parameters(), lr=args.lr)

    running_state = ZFilter((num_inputs,), clip=5.0)
    
    # record average 1-round cumulative reward in every episode
    reward_record = []
    global_steps = 0

    lr_now = args.lr
    clip_now = args.clip

    for i_episode in range(args.num_episode):
        # step1: perform current policy to collect trajectories
        # this is an on-policy method!
        memory = Memory()
        num_steps = 0
        reward_list = []
        len_list = []
        while num_steps < args.batch_size:
            state = env.reset()
            if args.state_norm:
                state = running_state(state)
            reward_sum = 0
            for t in range(args.max_step_per_round):
                action_mean, action_logstd, value = network(Tensor(state).unsqueeze(0))
                action, logproba = network.select_action(action_mean, action_logstd)
                action = action.data.numpy()[0]
                logproba = logproba.data.numpy()[0]
                next_state, reward, done, _ = env.step(action)
                reward_sum += reward
                if args.state_norm:
                    next_state = running_state(next_state)
                mask = 0 if done else 1

                memory.push(state, value, action, logproba, mask, next_state, reward)
                
                if done:
                    break
                    
                state = next_state
                
            num_steps += (t + 1)
            global_steps += (t + 1)
            reward_list.append(reward_sum)
            len_list.append(t + 1)
        reward_record.append({
            'episode': i_episode, 
            'steps': global_steps, 
            'meanepreward': np.mean(reward_list), 
            'meaneplen': np.mean(len_list)})

        batch = memory.sample()
        batch_size = len(memory)
        
        # step2: extract variables from trajectories
        rewards = Tensor(batch.reward)
        values = Tensor(batch.value)
        masks = Tensor(batch.mask)
        actions = Tensor(batch.action)
        states = Tensor(batch.state)
        oldlogproba = Tensor(batch.logproba)
        
        returns = Tensor(batch_size)
        deltas = Tensor(batch_size)
        advantages = Tensor(batch_size)

        prev_return = 0
        prev_value = 0
        prev_advantage = 0
        for i in reversed(range(batch_size)):
            returns[i] = rewards[i] + args.gamma * prev_return * masks[i]
            deltas[i] = rewards[i] + args.gamma * prev_value * masks[i] - values[i]
            # ref: https://arxiv.org/pdf/1506.02438.pdf (generalization advantage estimate)
            advantages[i] = deltas[i] + args.gamma * args.lamda * prev_advantage * masks[i]

            prev_return = returns[i]
            prev_value = values[i]
            prev_advantage = advantages[i]
        if args.advantage_norm:
            advantages = (advantages - advantages.mean()) / (advantages.std() + EPS)

        for i_epoch in range(int(args.num_epoch * batch_size / args.minibatch_size)):
            # sample from current batch
            minibatch_ind = np.random.choice(batch_size, args.minibatch_size, replace=False)
            minibatch_states = states[minibatch_ind]
            minibatch_actions = actions[minibatch_ind]
            minibatch_oldlogproba = oldlogproba[minibatch_ind]
            minibatch_newlogproba = network.get_logproba(minibatch_states, minibatch_actions)
            minibatch_advantages = advantages[minibatch_ind]
            minibatch_returns = returns[minibatch_ind]
            minibatch_newvalues = network._forward_critic(minibatch_states).flatten()

            ratio =  torch.exp(minibatch_newlogproba - minibatch_oldlogproba)
            surr1 = ratio * minibatch_advantages
            surr2 = ratio.clamp(1 - clip_now, 1 + clip_now) * minibatch_advantages
            loss_surr = - torch.mean(torch.min(surr1, surr2))

            # not sure the value loss should be clipped as well 
            # clip example: https://github.com/Jiankai-Sun/Proximal-Policy-Optimization-in-Pytorch/blob/master/ppo.py
            # however, it does not make sense to clip score-like value by a dimensionless clipping parameter
            # moreover, original paper does not mention clipped value 
            if args.lossvalue_norm:
                minibatch_return_6std = 6 * minibatch_returns.std()
                loss_value = torch.mean((minibatch_newvalues - minibatch_returns).pow(2)) / minibatch_return_6std
            else:
                loss_value = torch.mean((minibatch_newvalues - minibatch_returns).pow(2))

            loss_entropy = torch.mean(torch.exp(minibatch_newlogproba) * minibatch_newlogproba)

            total_loss = loss_surr + args.loss_coeff_value * loss_value + args.loss_coeff_entropy * loss_entropy
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        if args.schedule_clip == 'linear':
            ep_ratio = 1 - (i_episode / args.num_episode)
            clip_now = args.clip * ep_ratio

        if args.schedule_adam == 'linear':
            ep_ratio = 1 - (i_episode / args.num_episode)
            lr_now = args.lr * ep_ratio
            # set learning rate
            # ref: https://stackoverflow.com/questions/48324152/
            for g in optimizer.param_groups:
                g['lr'] = lr_now

        if i_episode % args.log_num_episode == 0:
            print('Finished episode: {} Reward: {:.4f} total_loss = {:.4f} = {:.4f} + {} * {:.4f} + {} * {:.4f}' \
                .format(i_episode, reward_record[-1]['meanepreward'], total_loss.data, loss_surr.data, args.loss_coeff_value, 
                loss_value.data, args.loss_coeff_entropy, loss_entropy.data))
            print('-----------------')

    return reward_record

def test(args):
    record_dfs = []
    for i in range(args.num_parallel_run):
        args.seed += 1
        reward_record = pd.DataFrame(ppo(args))
        reward_record['#parallel_run'] = i
        record_dfs.append(reward_record)
    record_dfs = pd.concat(record_dfs, axis=0)
    record_dfs.to_csv(joindir(RESULT_DIR, 'ppo-record-{}.csv'.format(args.env_name)))
    
if __name__ == '__main__':

    for env in ['Walker2d-v2', 'Swimmer-v2', 'Hopper-v2', 'Humanoid-v2', 'HalfCheetah-v2', 'Reacher-v2']:
        args.env_name = env
        test(args)
# Out:
# Finished episode: 0 Reward: -1.2879 total_loss = 0.3117 = 0.0094 + 0.5 * 0.6046 + 0.01 * -0.0036
# -----------------
# Finished episode: 1 Reward: 1.1712 total_loss = 0.3627 = 0.0039 + 0.5 * 0.7178 + 0.01 * -0.0034
# -----------------
# Finished episode: 2 Reward: 5.5048 total_loss = 0.5387 = -0.0069 + 0.5 * 1.0912 + 0.01 * -0.0037
# -----------------
# Finished episode: 3 Reward: 8.0447 total_loss = 0.6352 = -0.0013 + 0.5 * 1.2731 + 0.01 * -0.0039
# -----------------
# Finished episode: 4 Reward: 19.0148 total_loss = 1.1188 = 0.0112 + 0.5 * 2.2153 + 0.01 * -0.0041
# -----------------
# Finished episode: 5 Reward: 22.7930 total_loss = 1.7821 = -0.0076 + 0.5 * 3.5794 + 0.01 * -0.0036
# -----------------
# Finished episode: 6 Reward: 37.7295 total_loss = 2.1005 = 0.0620 + 0.5 * 4.0772 + 0.01 * -0.0045
# -----------------
# Finished episode: 7 Reward: 85.8704 total_loss = 5.7744 = -0.0326 + 0.5 * 11.6140 + 0.01 * -0.0041
# -----------------
# Finished episode: 8 Reward: 121.0541 total_loss = 7.0265 = 0.0492 + 0.5 * 13.9548 + 0.01 * -0.0045
# -----------------
# Finished episode: 9 Reward: 146.8057 total_loss = 6.3054 = -0.0300 + 0.5 * 12.6709 + 0.01 * -0.0045
# -----------------
# Finished episode: 10 Reward: 186.4762 total_loss = 9.0033 = -0.0457 + 0.5 * 18.0981 + 0.01 * -0.0046
# -----------------
# Finished episode: 11 Reward: 230.3461 total_loss = 12.7415 = 0.0183 + 0.5 * 25.4465 + 0.01 * -0.0051
# -----------------
# Finished episode: 12 Reward: 211.6370 total_loss = 10.3589 = -0.0522 + 0.5 * 20.8223 + 0.01 * -0.0045
# -----------------
# Finished episode: 13 Reward: 132.0139 total_loss = 4.5010 = -0.0423 + 0.5 * 9.0865 + 0.01 * -0.0045
# -----------------
# Finished episode: 14 Reward: 266.5171 total_loss = 13.6952 = -0.0777 + 0.5 * 27.5459 + 0.01 * -0.0049
# -----------------
# Finished episode: 15 Reward: 248.3363 total_loss = 8.1456 = -0.0165 + 0.5 * 16.3244 + 0.01 * -0.0043
# -----------------
# Finished episode: 16 Reward: 263.8713 total_loss = 10.8953 = -0.0602 + 0.5 * 21.9112 + 0.01 * -0.0049
# -----------------
# Finished episode: 17 Reward: 258.8113 total_loss = 10.7294 = 0.0542 + 0.5 * 21.3505 + 0.01 * -0.0046
# -----------------
# Finished episode: 18 Reward: 330.0396 total_loss = 11.3970 = -0.0561 + 0.5 * 22.9062 + 0.01 * -0.0051
# -----------------
# Finished episode: 19 Reward: 236.5031 total_loss = 7.4252 = 0.0172 + 0.5 * 14.8160 + 0.01 * -0.0045
# -----------------
# Finished episode: 20 Reward: 252.1482 total_loss = 10.6450 = -0.0784 + 0.5 * 21.4471 + 0.01 * -0.0048
# -----------------
# Finished episode: 21 Reward: 266.1054 total_loss = 13.3025 = -0.1021 + 0.5 * 26.8095 + 0.01 * -0.0054
# -----------------
# Finished episode: 22 Reward: 326.3259 total_loss = 11.0678 = -0.0907 + 0.5 * 22.3171 + 0.01 * -0.0048
# -----------------
# Finished episode: 23 Reward: 212.9860 total_loss = 6.5170 = -0.1387 + 0.5 * 13.3115 + 0.01 * -0.0045
# -----------------
# Finished episode: 24 Reward: 214.8737 total_loss = 5.5766 = 0.0052 + 0.5 * 11.1430 + 0.01 * -0.0047
# -----------------
# Finished episode: 25 Reward: 206.9111 total_loss = 6.6368 = -0.0232 + 0.5 * 13.3201 + 0.01 * -0.0048
# -----------------
# Finished episode: 26 Reward: 296.2379 total_loss = 11.2743 = -0.0002 + 0.5 * 22.5490 + 0.01 * -0.0050
# -----------------
# Finished episode: 27 Reward: 227.9900 total_loss = 6.2203 = -0.0214 + 0.5 * 12.4836 + 0.01 * -0.0050
# -----------------
# Finished episode: 28 Reward: 251.2019 total_loss = 7.2454 = -0.0932 + 0.5 * 14.6775 + 0.01 * -0.0051
# -----------------
# Finished episode: 29 Reward: 289.1743 total_loss = 10.7657 = -0.0273 + 0.5 * 21.5861 + 0.01 * -0.0050
# -----------------
# Finished episode: 30 Reward: 267.0778 total_loss = 8.1931 = 0.0972 + 0.5 * 16.1918 + 0.01 * -0.0050
# -----------------
# Finished episode: 31 Reward: 219.9649 total_loss = 4.6937 = -0.0124 + 0.5 * 9.4123 + 0.01 * -0.0051
# -----------------
# Finished episode: 32 Reward: 193.6373 total_loss = 4.6083 = -0.0925 + 0.5 * 9.4017 + 0.01 * -0.0049
# -----------------
# Finished episode: 33 Reward: 230.8467 total_loss = 5.4314 = -0.0380 + 0.5 * 10.9389 + 0.01 * -0.0047
# -----------------
# Finished episode: 34 Reward: 292.1750 total_loss = 9.6124 = -0.0685 + 0.5 * 19.3619 + 0.01 * -0.0043
# -----------------
# Finished episode: 35 Reward: 285.0460 total_loss = 7.9640 = -0.0796 + 0.5 * 16.0873 + 0.01 * -0.0047
# -----------------
# Finished episode: 36 Reward: 218.5315 total_loss = 4.6870 = -0.1166 + 0.5 * 9.6073 + 0.01 * -0.0045
# -----------------
# Finished episode: 37 Reward: 299.4407 total_loss = 8.1229 = -0.1480 + 0.5 * 16.5419 + 0.01 * -0.0044
# -----------------
# Finished episode: 38 Reward: 277.2958 total_loss = 8.5434 = -0.0996 + 0.5 * 17.2861 + 0.01 * -0.0045
# -----------------
# Finished episode: 39 Reward: 232.0242 total_loss = 5.8619 = -0.0470 + 0.5 * 11.8179 + 0.01 * -0.0048
# -----------------
# Finished episode: 40 Reward: 278.0088 total_loss = 6.4937 = -0.0810 + 0.5 * 13.1494 + 0.01 * -0.0047
# -----------------
# Finished episode: 41 Reward: 262.6977 total_loss = 6.7970 = -0.0813 + 0.5 * 13.7567 + 0.01 * -0.0045
# -----------------
# Finished episode: 42 Reward: 239.1897 total_loss = 4.0077 = -0.0096 + 0.5 * 8.0346 + 0.01 * -0.0045
# -----------------
# Finished episode: 43 Reward: 268.2178 total_loss = 5.9983 = -0.0732 + 0.5 * 12.1430 + 0.01 * -0.0048
# -----------------
# Finished episode: 44 Reward: 256.4176 total_loss = 4.6021 = -0.0099 + 0.5 * 9.2240 + 0.01 * -0.0052
# -----------------
# Finished episode: 45 Reward: 261.1914 total_loss = 5.7664 = -0.0258 + 0.5 * 11.5844 + 0.01 * -0.0047
# -----------------
# Finished episode: 46 Reward: 273.3798 total_loss = 5.7386 = -0.1369 + 0.5 * 11.7511 + 0.01 * -0.0047
# -----------------
# Finished episode: 47 Reward: 273.1802 total_loss = 5.2952 = -0.0328 + 0.5 * 10.6561 + 0.01 * -0.0046
# -----------------
# Finished episode: 48 Reward: 313.9530 total_loss = 6.4508 = -0.0618 + 0.5 * 13.0253 + 0.01 * -0.0047
# -----------------
# Finished episode: 49 Reward: 274.8335 total_loss = 7.0526 = -0.0578 + 0.5 * 14.2210 + 0.01 * -0.0049
# -----------------
# Finished episode: 50 Reward: 274.3610 total_loss = 5.6702 = 0.0327 + 0.5 * 11.2749 + 0.01 * -0.0048
# -----------------
# Finished episode: 51 Reward: 262.5332 total_loss = 4.9368 = 0.0301 + 0.5 * 9.8135 + 0.01 * -0.0050
# -----------------
# Finished episode: 52 Reward: 275.3603 total_loss = 4.8693 = 0.0712 + 0.5 * 9.5963 + 0.01 * -0.0049
# -----------------
# Finished episode: 53 Reward: 329.2872 total_loss = 3.8939 = -0.1145 + 0.5 * 8.0170 + 0.01 * -0.0044
# -----------------
# Finished episode: 54 Reward: 233.3535 total_loss = 2.9538 = 0.0275 + 0.5 * 5.8528 + 0.01 * -0.0048
# -----------------
# Finished episode: 55 Reward: 322.5099 total_loss = 5.5464 = -0.0544 + 0.5 * 11.2016 + 0.01 * -0.0045
# -----------------
# Finished episode: 56 Reward: 293.3496 total_loss = 3.9314 = 0.0133 + 0.5 * 7.8362 + 0.01 * -0.0052
# -----------------
# Finished episode: 57 Reward: 289.1794 total_loss = 4.8276 = -0.0389 + 0.5 * 9.7330 + 0.01 * -0.0049
# -----------------
# Finished episode: 58 Reward: 299.4328 total_loss = 3.8228 = -0.1170 + 0.5 * 7.8798 + 0.01 * -0.0048
# -----------------
# Finished episode: 59 Reward: 274.1196 total_loss = 3.1666 = -0.0178 + 0.5 * 6.3690 + 0.01 * -0.0051
# -----------------
# Finished episode: 60 Reward: 317.0293 total_loss = 4.2327 = -0.0604 + 0.5 * 8.5864 + 0.01 * -0.0048
# -----------------
# Finished episode: 61 Reward: 311.3205 total_loss = 5.0516 = -0.0559 + 0.5 * 10.2151 + 0.01 * -0.0055
# -----------------
# Finished episode: 62 Reward: 267.2290 total_loss = 2.8857 = -0.0871 + 0.5 * 5.9458 + 0.01 * -0.0046
# -----------------
# Finished episode: 63 Reward: 287.2543 total_loss = 3.8006 = -0.0162 + 0.5 * 7.6336 + 0.01 * -0.0049
# -----------------
# Finished episode: 64 Reward: 248.3733 total_loss = 2.6099 = 0.0273 + 0.5 * 5.1654 + 0.01 * -0.0052
# -----------------
# Finished episode: 65 Reward: 323.3917 total_loss = 4.9364 = -0.0275 + 0.5 * 9.9279 + 0.01 * -0.0048
# -----------------
# Finished episode: 66 Reward: 274.0394 total_loss = 3.0642 = -0.1231 + 0.5 * 6.3746 + 0.01 * -0.0055
# -----------------
# Finished episode: 67 Reward: 262.4038 total_loss = 2.7134 = -0.0584 + 0.5 * 5.5437 + 0.01 * -0.0050
# -----------------
# Finished episode: 68 Reward: 290.5739 total_loss = 3.4295 = -0.0249 + 0.5 * 6.9090 + 0.01 * -0.0048
# -----------------
# Finished episode: 69 Reward: 273.2216 total_loss = 2.4335 = 0.0393 + 0.5 * 4.7885 + 0.01 * -0.0051
# -----------------
# Finished episode: 70 Reward: 282.4383 total_loss = 2.8167 = -0.0422 + 0.5 * 5.7179 + 0.01 * -0.0058
# -----------------
# Finished episode: 71 Reward: 334.2741 total_loss = 3.8851 = -0.0840 + 0.5 * 7.9382 + 0.01 * -0.0051
# -----------------
# Finished episode: 72 Reward: 333.7252 total_loss = 4.0012 = -0.0292 + 0.5 * 8.0608 + 0.01 * -0.0049
# -----------------
# Finished episode: 73 Reward: 376.2391 total_loss = 4.6977 = 0.0117 + 0.5 * 9.3722 + 0.01 * -0.0054
# -----------------
# Finished episode: 74 Reward: 399.6986 total_loss = 4.9157 = -0.0675 + 0.5 * 9.9665 + 0.01 * -0.0053
# -----------------
# Finished episode: 75 Reward: 298.5119 total_loss = 2.5870 = -0.0165 + 0.5 * 5.2070 + 0.01 * -0.0046
# -----------------
# Finished episode: 76 Reward: 359.3043 total_loss = 3.9656 = -0.0974 + 0.5 * 8.1262 + 0.01 * -0.0055
# -----------------
# Finished episode: 77 Reward: 326.8635 total_loss = 3.7621 = 0.0198 + 0.5 * 7.4847 + 0.01 * -0.0054
# -----------------
# Finished episode: 78 Reward: 339.2131 total_loss = 3.5248 = 0.0791 + 0.5 * 6.8915 + 0.01 * -0.0045
# -----------------
# Finished episode: 79 Reward: 360.2246 total_loss = 4.0263 = 0.1196 + 0.5 * 7.8136 + 0.01 * -0.0052
# -----------------
# Finished episode: 80 Reward: 333.6101 total_loss = 3.7099 = 0.0253 + 0.5 * 7.3694 + 0.01 * -0.0052
# -----------------
# Finished episode: 81 Reward: 381.6217 total_loss = 3.5242 = 0.0457 + 0.5 * 6.9570 + 0.01 * -0.0051
# -----------------
# Finished episode: 82 Reward: 316.3844 total_loss = 2.8156 = 0.1205 + 0.5 * 5.3902 + 0.01 * -0.0052
# -----------------
# Finished episode: 83 Reward: 417.4770 total_loss = 3.1258 = 0.0265 + 0.5 * 6.1987 + 0.01 * -0.0051
# -----------------
# Finished episode: 84 Reward: 349.5551 total_loss = 3.4534 = -0.0284 + 0.5 * 6.9637 + 0.01 * -0.0049
# -----------------
# Finished episode: 85 Reward: 348.9997 total_loss = 4.0520 = 0.0141 + 0.5 * 8.0758 + 0.01 * -0.0047
# -----------------
# Finished episode: 86 Reward: 314.6111 total_loss = 2.9470 = -0.1384 + 0.5 * 6.1709 + 0.01 * -0.0048
# -----------------
# Finished episode: 87 Reward: 346.4350 total_loss = 2.9589 = -0.0198 + 0.5 * 5.9575 + 0.01 * -0.0054
# -----------------
# Finished episode: 88 Reward: 380.5297 total_loss = 3.2084 = -0.0291 + 0.5 * 6.4752 + 0.01 * -0.0051
# -----------------
# Finished episode: 89 Reward: 471.5506 total_loss = 6.8108 = 0.0028 + 0.5 * 13.6162 + 0.01 * -0.0058
# -----------------
# Finished episode: 90 Reward: 436.4427 total_loss = 3.3268 = -0.1177 + 0.5 * 6.8891 + 0.01 * -0.0048
# -----------------
# Finished episode: 91 Reward: 378.3646 total_loss = 3.6687 = 0.1250 + 0.5 * 7.0875 + 0.01 * -0.0057
# -----------------
# Finished episode: 92 Reward: 404.7891 total_loss = 2.5878 = 0.0605 + 0.5 * 5.0547 + 0.01 * -0.0060
# -----------------
# Finished episode: 93 Reward: 461.7510 total_loss = 5.1314 = -0.0308 + 0.5 * 10.3247 + 0.01 * -0.0055
# -----------------
# Finished episode: 94 Reward: 430.1660 total_loss = 3.6523 = 0.0183 + 0.5 * 7.2681 + 0.01 * -0.0059
# -----------------
# Finished episode: 95 Reward: 475.0126 total_loss = 5.2483 = -0.0655 + 0.5 * 10.6278 + 0.01 * -0.0056
# -----------------
# Finished episode: 96 Reward: 473.0941 total_loss = 4.3474 = -0.0219 + 0.5 * 8.7387 + 0.01 * -0.0067
# -----------------
# Finished episode: 97 Reward: 384.1851 total_loss = 2.4869 = -0.0499 + 0.5 * 5.0736 + 0.01 * -0.0058
# -----------------
# Finished episode: 98 Reward: 487.5617 total_loss = 4.7604 = -0.0701 + 0.5 * 9.6613 + 0.01 * -0.0057
# -----------------
# Finished episode: 99 Reward: 555.4166 total_loss = 5.5720 = 0.0725 + 0.5 * 10.9990 + 0.01 * -0.0060
# -----------------
# Finished episode: 100 Reward: 567.2915 total_loss = 6.5207 = -0.0782 + 0.5 * 13.1978 + 0.01 * -0.0059
# -----------------
# Finished episode: 101 Reward: 517.6033 total_loss = 5.4972 = -0.0397 + 0.5 * 11.0739 + 0.01 * -0.0056
# -----------------
# Finished episode: 102 Reward: 481.3055 total_loss = 4.8209 = -0.0618 + 0.5 * 9.7654 + 0.01 * -0.0054
# -----------------
# Finished episode: 103 Reward: 544.2851 total_loss = 5.2030 = -0.0326 + 0.5 * 10.4714 + 0.01 * -0.0059
# -----------------
# Finished episode: 104 Reward: 467.0763 total_loss = 3.2202 = -0.0024 + 0.5 * 6.4453 + 0.01 * -0.0064
# -----------------
# Finished episode: 105 Reward: 500.4418 total_loss = 5.5328 = -0.0362 + 0.5 * 11.1382 + 0.01 * -0.0058
# -----------------
# Finished episode: 106 Reward: 450.7006 total_loss = 2.7818 = -0.0006 + 0.5 * 5.5648 + 0.01 * -0.0055
# -----------------
# Finished episode: 107 Reward: 530.1032 total_loss = 3.3158 = 0.0521 + 0.5 * 6.5275 + 0.01 * -0.0065
# -----------------
# Finished episode: 108 Reward: 463.9753 total_loss = 4.7443 = -0.1139 + 0.5 * 9.7167 + 0.01 * -0.0062
# -----------------
# Finished episode: 109 Reward: 500.7256 total_loss = 5.8990 = -0.0252 + 0.5 * 11.8485 + 0.01 * -0.0061
# -----------------
# Finished episode: 110 Reward: 398.1217 total_loss = 2.6916 = 0.0427 + 0.5 * 5.2979 + 0.01 * -0.0060
# -----------------
# Finished episode: 111 Reward: 460.8019 total_loss = 2.5809 = -0.0261 + 0.5 * 5.2140 + 0.01 * -0.0062
# -----------------
# Finished episode: 112 Reward: 426.9074 total_loss = 2.2418 = -0.0477 + 0.5 * 4.5792 + 0.01 * -0.0059
# -----------------
# Finished episode: 113 Reward: 379.6607 total_loss = 2.2991 = 0.0480 + 0.5 * 4.5023 + 0.01 * -0.0063
# -----------------
# Finished episode: 114 Reward: 504.6749 total_loss = 4.0116 = -0.0154 + 0.5 * 8.0541 + 0.01 * -0.0061
# -----------------
# Finished episode: 115 Reward: 424.6606 total_loss = 1.8951 = 0.0780 + 0.5 * 3.6344 + 0.01 * -0.0060
# -----------------
# Finished episode: 116 Reward: 497.3763 total_loss = 2.7781 = -0.0370 + 0.5 * 5.6303 + 0.01 * -0.0070
# -----------------
# Finished episode: 117 Reward: 423.9114 total_loss = 3.3728 = -0.0036 + 0.5 * 6.7528 + 0.01 * -0.0060
# -----------------
# Finished episode: 118 Reward: 529.2105 total_loss = 3.8922 = -0.0641 + 0.5 * 7.9126 + 0.01 * -0.0070
# -----------------
# Finished episode: 119 Reward: 472.9745 total_loss = 3.5250 = -0.0003 + 0.5 * 7.0507 + 0.01 * -0.0063
# -----------------
# Finished episode: 120 Reward: 448.6645 total_loss = 2.3266 = -0.0222 + 0.5 * 4.6977 + 0.01 * -0.0060
# -----------------
# Finished episode: 121 Reward: 447.1324 total_loss = 3.7708 = -0.0022 + 0.5 * 7.5461 + 0.01 * -0.0062
# -----------------
# Finished episode: 122 Reward: 441.3285 total_loss = 2.6485 = 0.0931 + 0.5 * 5.1109 + 0.01 * -0.0068
# -----------------
# Finished episode: 123 Reward: 473.5726 total_loss = 3.2217 = 0.0677 + 0.5 * 6.3083 + 0.01 * -0.0067
# -----------------
# Finished episode: 124 Reward: 410.5934 total_loss = 2.4935 = -0.0611 + 0.5 * 5.1092 + 0.01 * -0.0072
# -----------------
# Finished episode: 125 Reward: 485.2861 total_loss = 4.1531 = -0.0341 + 0.5 * 8.3746 + 0.01 * -0.0074
# -----------------
# Finished episode: 126 Reward: 642.5474 total_loss = 4.4631 = 0.0247 + 0.5 * 8.8769 + 0.01 * -0.0065
# -----------------
# Finished episode: 127 Reward: 440.7536 total_loss = 2.8593 = -0.0522 + 0.5 * 5.8232 + 0.01 * -0.0080
# -----------------
# Finished episode: 128 Reward: 547.2353 total_loss = 4.1962 = -0.0171 + 0.5 * 8.4268 + 0.01 * -0.0065
# -----------------
# Finished episode: 129 Reward: 526.5671 total_loss = 2.2205 = 0.0034 + 0.5 * 4.4343 + 0.01 * -0.0065
# -----------------
# Finished episode: 130 Reward: 500.2180 total_loss = 1.1997 = 0.0257 + 0.5 * 2.3481 + 0.01 * -0.0077
# -----------------
# Finished episode: 131 Reward: 521.6029 total_loss = 3.4077 = -0.0052 + 0.5 * 6.8259 + 0.01 * -0.0072
# -----------------
# Finished episode: 132 Reward: 569.0392 total_loss = 5.5595 = -0.0983 + 0.5 * 11.3158 + 0.01 * -0.0078
# -----------------
# Finished episode: 133 Reward: 589.1477 total_loss = 6.6549 = 0.0466 + 0.5 * 13.2169 + 0.01 * -0.0078
# -----------------
# Finished episode: 134 Reward: 453.7580 total_loss = 1.2911 = -0.0774 + 0.5 * 2.7371 + 0.01 * -0.0076
# -----------------
# Finished episode: 135 Reward: 481.8533 total_loss = 2.1423 = -0.0006 + 0.5 * 4.2860 + 0.01 * -0.0081
# -----------------
# Finished episode: 136 Reward: 538.3357 total_loss = 1.8247 = -0.1443 + 0.5 * 3.9383 + 0.01 * -0.0083
# -----------------
# Finished episode: 137 Reward: 636.0921 total_loss = 7.7113 = -0.0938 + 0.5 * 15.6104 + 0.01 * -0.0076
# -----------------
# Finished episode: 138 Reward: 562.2857 total_loss = 3.4581 = 0.0189 + 0.5 * 6.8784 + 0.01 * -0.0077
# -----------------
# Finished episode: 139 Reward: 563.1885 total_loss = 1.6193 = -0.0247 + 0.5 * 3.2881 + 0.01 * -0.0073
# -----------------
# Finished episode: 140 Reward: 580.4315 total_loss = 4.8657 = -0.1531 + 0.5 * 10.0377 + 0.01 * -0.0074
# -----------------
# Finished episode: 141 Reward: 591.5713 total_loss = 5.6418 = -0.0638 + 0.5 * 11.4113 + 0.01 * -0.0078
# -----------------
# Finished episode: 142 Reward: 567.7735 total_loss = 4.0787 = -0.0062 + 0.5 * 8.1700 + 0.01 * -0.0080
# -----------------
# Finished episode: 143 Reward: 442.4320 total_loss = 2.5461 = 0.0574 + 0.5 * 4.9776 + 0.01 * -0.0078
# -----------------
# Finished episode: 144 Reward: 584.2290 total_loss = 3.9049 = -0.1482 + 0.5 * 8.1063 + 0.01 * -0.0077
# -----------------
# Finished episode: 145 Reward: 727.8127 total_loss = 8.1779 = -0.1236 + 0.5 * 16.6031 + 0.01 * -0.0075
# -----------------
# Finished episode: 146 Reward: 670.1767 total_loss = 4.9416 = -0.0949 + 0.5 * 10.0732 + 0.01 * -0.0087
# -----------------
# Finished episode: 147 Reward: 672.1415 total_loss = 4.6266 = 0.0378 + 0.5 * 9.1780 + 0.01 * -0.0087
# -----------------
# Finished episode: 148 Reward: 919.8560 total_loss = 7.2263 = 0.0980 + 0.5 * 14.2567 + 0.01 * -0.0087
# -----------------
# Finished episode: 149 Reward: 684.4272 total_loss = 5.1616 = -0.0389 + 0.5 * 10.4012 + 0.01 * -0.0083
# -----------------
# Finished episode: 150 Reward: 710.4105 total_loss = 4.5672 = -0.0413 + 0.5 * 9.2171 + 0.01 * -0.0085
# -----------------
# Finished episode: 151 Reward: 645.2396 total_loss = 4.4059 = -0.0053 + 0.5 * 8.8226 + 0.01 * -0.0082
# -----------------
# Finished episode: 152 Reward: 729.5887 total_loss = 5.7193 = -0.0921 + 0.5 * 11.6230 + 0.01 * -0.0079
# -----------------
# Finished episode: 153 Reward: 774.5377 total_loss = 7.2183 = -0.1083 + 0.5 * 14.6534 + 0.01 * -0.0077
# -----------------
# Finished episode: 154 Reward: 533.2546 total_loss = 3.2255 = 0.0671 + 0.5 * 6.3169 + 0.01 * -0.0086
# -----------------
# Finished episode: 155 Reward: 691.7027 total_loss = 5.2255 = -0.1042 + 0.5 * 10.6596 + 0.01 * -0.0082
# -----------------
# Finished episode: 156 Reward: 706.3333 total_loss = 6.8333 = -0.0014 + 0.5 * 13.6696 + 0.01 * -0.0085
# -----------------
# Finished episode: 157 Reward: 730.6682 total_loss = 3.8865 = -0.0611 + 0.5 * 7.8953 + 0.01 * -0.0081
# -----------------
# Finished episode: 158 Reward: 603.0582 total_loss = 5.3727 = -0.0431 + 0.5 * 10.8318 + 0.01 * -0.0081
# -----------------
# Finished episode: 159 Reward: 587.0384 total_loss = 3.0817 = -0.0061 + 0.5 * 6.1757 + 0.01 * -0.0090
# -----------------
# Finished episode: 160 Reward: 875.5576 total_loss = 8.1057 = -0.0252 + 0.5 * 16.2620 + 0.01 * -0.0081
# -----------------
# Finished episode: 161 Reward: 510.2453 total_loss = 4.1823 = 0.0242 + 0.5 * 8.3164 + 0.01 * -0.0093
# -----------------
# Finished episode: 162 Reward: 609.0231 total_loss = 5.3744 = -0.0161 + 0.5 * 10.7811 + 0.01 * -0.0084
# -----------------
# Finished episode: 163 Reward: 1027.2703 total_loss = 6.3028 = 0.0400 + 0.5 * 12.5258 + 0.01 * -0.0087
# -----------------
# Finished episode: 164 Reward: 519.0862 total_loss = 3.0983 = -0.0695 + 0.5 * 6.3359 + 0.01 * -0.0089
# -----------------
# Finished episode: 165 Reward: 679.5343 total_loss = 4.4581 = -0.0480 + 0.5 * 9.0124 + 0.01 * -0.0084
# -----------------
# Finished episode: 166 Reward: 703.6950 total_loss = 6.4753 = -0.0591 + 0.5 * 13.0689 + 0.01 * -0.0090
# -----------------
# Finished episode: 167 Reward: 1024.0705 total_loss = 8.4839 = -0.0180 + 0.5 * 17.0040 + 0.01 * -0.0090
# -----------------
# Finished episode: 168 Reward: 870.1730 total_loss = 9.5206 = -0.0754 + 0.5 * 19.1921 + 0.01 * -0.0087
# -----------------
# Finished episode: 169 Reward: 1287.1488 total_loss = 14.5859 = -0.0302 + 0.5 * 29.2323 + 0.01 * -0.0089
# -----------------
# Finished episode: 170 Reward: 867.7136 total_loss = 5.8544 = -0.0375 + 0.5 * 11.7841 + 0.01 * -0.0101
# -----------------
# Finished episode: 171 Reward: 1074.7450 total_loss = 10.4840 = -0.0696 + 0.5 * 21.1074 + 0.01 * -0.0092
# -----------------
# Finished episode: 172 Reward: 934.7857 total_loss = 8.3258 = -0.0699 + 0.5 * 16.7916 + 0.01 * -0.0094
# -----------------
# Finished episode: 173 Reward: 616.9523 total_loss = 4.0838 = 0.0850 + 0.5 * 7.9978 + 0.01 * -0.0096
# -----------------
# Finished episode: 174 Reward: 893.8024 total_loss = 7.6873 = 0.0256 + 0.5 * 15.3238 + 0.01 * -0.0111
# -----------------
# Finished episode: 175 Reward: 972.7026 total_loss = 9.3477 = -0.1366 + 0.5 * 18.9688 + 0.01 * -0.0096
# -----------------
# Finished episode: 176 Reward: 674.6212 total_loss = 6.6879 = -0.0648 + 0.5 * 13.5054 + 0.01 * -0.0092
# -----------------
# Finished episode: 177 Reward: 861.0716 total_loss = 4.5315 = -0.0378 + 0.5 * 9.1389 + 0.01 * -0.0102
# -----------------
# Finished episode: 178 Reward: 956.2210 total_loss = 9.2814 = 0.0036 + 0.5 * 18.5557 + 0.01 * -0.0098
# -----------------
# Finished episode: 179 Reward: 626.6298 total_loss = 4.2840 = -0.0033 + 0.5 * 8.5748 + 0.01 * -0.0095
# -----------------
# Finished episode: 180 Reward: 948.4315 total_loss = 7.9460 = 0.0228 + 0.5 * 15.8467 + 0.01 * -0.0098
# -----------------
# Finished episode: 181 Reward: 1048.7336 total_loss = 12.6052 = -0.0568 + 0.5 * 25.3241 + 0.01 * -0.0100
# -----------------
# Finished episode: 182 Reward: 979.7118 total_loss = 8.9596 = -0.0807 + 0.5 * 18.0808 + 0.01 * -0.0119
# -----------------
# Finished episode: 183 Reward: 1321.2037 total_loss = 13.0748 = -0.0020 + 0.5 * 26.1538 + 0.01 * -0.0110
# -----------------
# Finished episode: 184 Reward: 828.6832 total_loss = 6.3069 = -0.0765 + 0.5 * 12.7669 + 0.01 * -0.0116
# -----------------
# Finished episode: 185 Reward: 733.2109 total_loss = 6.0686 = 0.0133 + 0.5 * 12.1109 + 0.01 * -0.0106
# -----------------
# Finished episode: 186 Reward: 1112.2833 total_loss = 9.1647 = -0.0920 + 0.5 * 18.5135 + 0.01 * -0.0109
# -----------------
# Finished episode: 187 Reward: 897.3818 total_loss = 8.0070 = -0.0536 + 0.5 * 16.1215 + 0.01 * -0.0108
# -----------------
# Finished episode: 188 Reward: 839.7483 total_loss = 4.0452 = -0.0218 + 0.5 * 8.1343 + 0.01 * -0.0116
# -----------------
# Finished episode: 189 Reward: 1360.1570 total_loss = 12.6096 = -0.0720 + 0.5 * 25.3634 + 0.01 * -0.0107
# -----------------
# Finished episode: 190 Reward: 606.2193 total_loss = 5.2187 = -0.0170 + 0.5 * 10.4715 + 0.01 * -0.0113
# -----------------
# Finished episode: 191 Reward: 972.2006 total_loss = 4.1675 = -0.0119 + 0.5 * 8.3591 + 0.01 * -0.0113
# -----------------
# Finished episode: 192 Reward: 749.1756 total_loss = 5.0074 = -0.1108 + 0.5 * 10.2367 + 0.01 * -0.0124
# -----------------
# Finished episode: 193 Reward: 859.2750 total_loss = 5.3269 = -0.1292 + 0.5 * 10.9124 + 0.01 * -0.0129
# -----------------
# Finished episode: 194 Reward: 763.3284 total_loss = 8.2286 = -0.0059 + 0.5 * 16.4692 + 0.01 * -0.0131
# -----------------
# Finished episode: 195 Reward: 909.7783 total_loss = 6.5104 = -0.0391 + 0.5 * 13.0991 + 0.01 * -0.0122
# -----------------
# Finished episode: 196 Reward: 1438.5024 total_loss = 10.0645 = 0.0102 + 0.5 * 20.1089 + 0.01 * -0.0109
# -----------------
# Finished episode: 197 Reward: 1092.8651 total_loss = 9.2820 = -0.0341 + 0.5 * 18.6325 + 0.01 * -0.0126
# -----------------
# Finished episode: 198 Reward: 932.7863 total_loss = 6.1407 = -0.0573 + 0.5 * 12.3963 + 0.01 * -0.0127
# -----------------
# Finished episode: 199 Reward: 1050.6751 total_loss = 7.4667 = -0.0653 + 0.5 * 15.0644 + 0.01 * -0.0126
# -----------------
# Finished episode: 200 Reward: 1007.2618 total_loss = 8.9573 = -0.0377 + 0.5 * 17.9903 + 0.01 * -0.0127
# -----------------
# Finished episode: 201 Reward: 1387.7553 total_loss = 14.2285 = -0.0183 + 0.5 * 28.4939 + 0.01 * -0.0128
# -----------------
# Finished episode: 202 Reward: 713.5205 total_loss = 8.8476 = 0.0665 + 0.5 * 17.5624 + 0.01 * -0.0122
# -----------------
# Finished episode: 203 Reward: 1203.5808 total_loss = 6.6816 = -0.0165 + 0.5 * 13.3963 + 0.01 * -0.0119
# -----------------
# Finished episode: 204 Reward: 1114.1910 total_loss = 6.2963 = 0.0917 + 0.5 * 12.4095 + 0.01 * -0.0117
# -----------------
# Finished episode: 205 Reward: 1557.3810 total_loss = 9.1121 = -0.0824 + 0.5 * 18.3891 + 0.01 * -0.0119
# -----------------
# Finished episode: 206 Reward: 821.8021 total_loss = 5.7836 = -0.0163 + 0.5 * 11.6000 + 0.01 * -0.0119
# -----------------
# Finished episode: 207 Reward: 1118.6958 total_loss = 9.0806 = -0.0030 + 0.5 * 18.1676 + 0.01 * -0.0130
# -----------------
# Finished episode: 208 Reward: 977.5993 total_loss = 5.3071 = 0.0037 + 0.5 * 10.6070 + 0.01 * -0.0108
# -----------------
# Finished episode: 209 Reward: 1070.0438 total_loss = 5.5636 = 0.0118 + 0.5 * 11.1039 + 0.01 * -0.0122
# -----------------
# Finished episode: 210 Reward: 1395.0217 total_loss = 9.1315 = -0.0494 + 0.5 * 18.3621 + 0.01 * -0.0112
# -----------------
# Finished episode: 211 Reward: 1286.0353 total_loss = 5.4016 = -0.0066 + 0.5 * 10.8166 + 0.01 * -0.0117
# -----------------
# Finished episode: 212 Reward: 1060.3058 total_loss = 6.7418 = 0.0335 + 0.5 * 13.4170 + 0.01 * -0.0122
# -----------------
# Finished episode: 213 Reward: 1204.1392 total_loss = 9.7693 = -0.0584 + 0.5 * 19.6556 + 0.01 * -0.0120
# -----------------
# Finished episode: 214 Reward: 980.7845 total_loss = 5.8141 = -0.0380 + 0.5 * 11.7044 + 0.01 * -0.0107
# -----------------
# Finished episode: 215 Reward: 1007.9625 total_loss = 5.8274 = -0.0834 + 0.5 * 11.8219 + 0.01 * -0.0134
# -----------------
# Finished episode: 216 Reward: 1275.5142 total_loss = 5.9326 = -0.0121 + 0.5 * 11.8898 + 0.01 * -0.0136
# -----------------
# Finished episode: 217 Reward: 2160.9354 total_loss = 15.4488 = -0.0063 + 0.5 * 30.9105 + 0.01 * -0.0138
# -----------------
# Finished episode: 218 Reward: 993.9800 total_loss = 7.1445 = 0.0204 + 0.5 * 14.2486 + 0.01 * -0.0124
# -----------------
# Finished episode: 219 Reward: 1090.3427 total_loss = 5.6941 = -0.0125 + 0.5 * 11.4135 + 0.01 * -0.0136
# -----------------
# Finished episode: 220 Reward: 1350.3117 total_loss = 8.1348 = 0.0276 + 0.5 * 16.2148 + 0.01 * -0.0143
# -----------------
# Finished episode: 221 Reward: 795.1226 total_loss = 5.1308 = 0.0023 + 0.5 * 10.2572 + 0.01 * -0.0127
# -----------------
# Finished episode: 222 Reward: 1306.3212 total_loss = 8.5933 = -0.0633 + 0.5 * 17.3136 + 0.01 * -0.0134
# -----------------
# Finished episode: 223 Reward: 1261.1765 total_loss = 10.6590 = -0.0012 + 0.5 * 21.3207 + 0.01 * -0.0132
# -----------------
# Finished episode: 224 Reward: 1152.6966 total_loss = 8.1948 = -0.0344 + 0.5 * 16.4587 + 0.01 * -0.0140
# -----------------
# Finished episode: 225 Reward: 1037.2587 total_loss = 6.7287 = -0.0705 + 0.5 * 13.5986 + 0.01 * -0.0130
# -----------------
# Finished episode: 226 Reward: 1173.2231 total_loss = 7.5888 = -0.0936 + 0.5 * 15.3652 + 0.01 * -0.0140
# -----------------
# Finished episode: 227 Reward: 961.7080 total_loss = 6.9412 = 0.0167 + 0.5 * 13.8492 + 0.01 * -0.0126
# -----------------
# Finished episode: 228 Reward: 1101.7242 total_loss = 5.4750 = -0.0896 + 0.5 * 11.1295 + 0.01 * -0.0134
# -----------------
# Finished episode: 229 Reward: 2054.0393 total_loss = 15.5071 = 0.0161 + 0.5 * 30.9824 + 0.01 * -0.0151
# -----------------
# Finished episode: 230 Reward: 1396.0198 total_loss = 6.1474 = -0.0519 + 0.5 * 12.3988 + 0.01 * -0.0127
# -----------------
# Finished episode: 231 Reward: 1190.2584 total_loss = 6.8946 = -0.1164 + 0.5 * 14.0221 + 0.01 * -0.0132
# -----------------
# Finished episode: 232 Reward: 1207.2696 total_loss = 10.7610 = -0.0696 + 0.5 * 21.6615 + 0.01 * -0.0134
# -----------------
# Finished episode: 233 Reward: 1183.7822 total_loss = 10.2310 = 0.0303 + 0.5 * 20.4015 + 0.01 * -0.0124
# -----------------
# Finished episode: 234 Reward: 926.6422 total_loss = 7.4761 = 0.0533 + 0.5 * 14.8459 + 0.01 * -0.0129
# -----------------
# Finished episode: 235 Reward: 1488.0059 total_loss = 6.1305 = -0.1369 + 0.5 * 12.5350 + 0.01 * -0.0128
# -----------------
# Finished episode: 236 Reward: 1360.6525 total_loss = 6.3956 = -0.0081 + 0.5 * 12.8077 + 0.01 * -0.0140
# -----------------
# Finished episode: 237 Reward: 2169.1146 total_loss = 12.1405 = -0.0615 + 0.5 * 24.4043 + 0.01 * -0.0141
# -----------------
# Finished episode: 238 Reward: 1744.0653 total_loss = 11.1137 = -0.0398 + 0.5 * 22.3074 + 0.01 * -0.0131
# -----------------
# Finished episode: 239 Reward: 1422.4255 total_loss = 8.2077 = -0.0374 + 0.5 * 16.4905 + 0.01 * -0.0122
# -----------------
# Finished episode: 240 Reward: 1204.1142 total_loss = 8.8364 = -0.0708 + 0.5 * 17.8147 + 0.01 * -0.0135
# -----------------
# Finished episode: 241 Reward: 1261.6460 total_loss = 5.6984 = -0.0125 + 0.5 * 11.4221 + 0.01 * -0.0161
# -----------------
# Finished episode: 242 Reward: 1550.0670 total_loss = 7.9698 = 0.0020 + 0.5 * 15.9360 + 0.01 * -0.0137
# -----------------
# Finished episode: 243 Reward: 1666.8735 total_loss = 12.5866 = -0.0348 + 0.5 * 25.2431 + 0.01 * -0.0138
# -----------------
# Finished episode: 244 Reward: 1273.6941 total_loss = 4.3179 = -0.0840 + 0.5 * 8.8041 + 0.01 * -0.0168
# -----------------
# Finished episode: 245 Reward: 1412.3167 total_loss = 9.8384 = -0.0383 + 0.5 * 19.7538 + 0.01 * -0.0142
# -----------------
# Finished episode: 246 Reward: 1107.2585 total_loss = 6.6139 = -0.0249 + 0.5 * 13.2779 + 0.01 * -0.0131
# -----------------
# Finished episode: 247 Reward: 1260.7667 total_loss = 7.2803 = -0.0172 + 0.5 * 14.5952 + 0.01 * -0.0136
# -----------------
# Finished episode: 248 Reward: 1336.9633 total_loss = 7.4200 = 0.0027 + 0.5 * 14.8349 + 0.01 * -0.0141
# -----------------
# Finished episode: 249 Reward: 2172.6490 total_loss = 7.9784 = 0.0006 + 0.5 * 15.9559 + 0.01 * -0.0128
# -----------------
# Finished episode: 250 Reward: 1809.5996 total_loss = 8.0437 = -0.0192 + 0.5 * 16.1262 + 0.01 * -0.0153
# -----------------
# Finished episode: 251 Reward: 1457.4514 total_loss = 7.3950 = 0.0537 + 0.5 * 14.6829 + 0.01 * -0.0161
# -----------------
# Finished episode: 252 Reward: 1176.8459 total_loss = 6.2188 = -0.0189 + 0.5 * 12.4757 + 0.01 * -0.0138
# -----------------
# Finished episode: 253 Reward: 1672.6671 total_loss = 6.8386 = -0.0863 + 0.5 * 13.8500 + 0.01 * -0.0133
# -----------------
# Finished episode: 254 Reward: 1068.2780 total_loss = 6.3628 = -0.0807 + 0.5 * 12.8874 + 0.01 * -0.0144
# -----------------
# Finished episode: 255 Reward: 1324.3788 total_loss = 7.9161 = -0.1185 + 0.5 * 16.0695 + 0.01 * -0.0139
# -----------------
# Finished episode: 256 Reward: 1048.9832 total_loss = 3.6893 = 0.0352 + 0.5 * 7.3085 + 0.01 * -0.0145
# -----------------
# Finished episode: 257 Reward: 1050.5829 total_loss = 4.5172 = 0.0226 + 0.5 * 8.9895 + 0.01 * -0.0144
# -----------------
# Finished episode: 258 Reward: 1304.6249 total_loss = 7.9465 = -0.0406 + 0.5 * 15.9745 + 0.01 * -0.0156
# -----------------
# Finished episode: 259 Reward: 1180.0872 total_loss = 3.9919 = 0.0144 + 0.5 * 7.9554 + 0.01 * -0.0156
# -----------------
# Finished episode: 260 Reward: 1354.4946 total_loss = 7.9114 = -0.0321 + 0.5 * 15.8874 + 0.01 * -0.0161
# -----------------
# Finished episode: 261 Reward: 1465.6922 total_loss = 5.6344 = 0.0014 + 0.5 * 11.2663 + 0.01 * -0.0146
# -----------------
# Finished episode: 262 Reward: 1485.1682 total_loss = 5.4470 = -0.0361 + 0.5 * 10.9666 + 0.01 * -0.0150
# -----------------
# Finished episode: 263 Reward: 1489.0551 total_loss = 8.8549 = -0.0999 + 0.5 * 17.9099 + 0.01 * -0.0157
# -----------------
# Finished episode: 264 Reward: 1618.5440 total_loss = 6.3068 = -0.0905 + 0.5 * 12.7950 + 0.01 * -0.0164
# -----------------
# Finished episode: 265 Reward: 1362.5038 total_loss = 4.6096 = -0.0419 + 0.5 * 9.3034 + 0.01 * -0.0153
# -----------------
# Finished episode: 266 Reward: 1274.3329 total_loss = 7.7920 = -0.0207 + 0.5 * 15.6258 + 0.01 * -0.0153
# -----------------
# Finished episode: 267 Reward: 1284.2238 total_loss = 8.2092 = -0.0562 + 0.5 * 16.5311 + 0.01 * -0.0159
# -----------------
# Finished episode: 268 Reward: 1286.1811 total_loss = 6.0627 = 0.0227 + 0.5 * 12.0803 + 0.01 * -0.0145
# -----------------
# Finished episode: 269 Reward: 1354.1578 total_loss = 6.2700 = -0.0171 + 0.5 * 12.5744 + 0.01 * -0.0132
# -----------------
# Finished episode: 270 Reward: 2466.7544 total_loss = 16.4709 = -0.0186 + 0.5 * 32.9793 + 0.01 * -0.0155
# -----------------
# Finished episode: 271 Reward: 1417.2965 total_loss = 4.1512 = -0.0000 + 0.5 * 8.3028 + 0.01 * -0.0141
# -----------------
# Finished episode: 272 Reward: 1385.1279 total_loss = 7.9483 = 0.0571 + 0.5 * 15.7828 + 0.01 * -0.0150
# -----------------
# Finished episode: 273 Reward: 1305.9263 total_loss = 6.3497 = 0.0021 + 0.5 * 12.6954 + 0.01 * -0.0151
# -----------------
# Finished episode: 274 Reward: 2409.5694 total_loss = 10.7198 = -0.0459 + 0.5 * 21.5317 + 0.01 * -0.0169
# -----------------
# Finished episode: 275 Reward: 2293.9053 total_loss = 10.0821 = -0.0586 + 0.5 * 20.2817 + 0.01 * -0.0166
# -----------------
# Finished episode: 276 Reward: 1310.1411 total_loss = 6.3005 = 0.0858 + 0.5 * 12.4298 + 0.01 * -0.0151
# -----------------
# Finished episode: 277 Reward: 1626.7912 total_loss = 4.7916 = -0.1144 + 0.5 * 9.8123 + 0.01 * -0.0159
# -----------------
# Finished episode: 278 Reward: 1708.9549 total_loss = 8.7294 = 0.0030 + 0.5 * 17.4531 + 0.01 * -0.0164
# -----------------
# Finished episode: 279 Reward: 2079.5586 total_loss = 10.6121 = -0.0109 + 0.5 * 21.2463 + 0.01 * -0.0134
# -----------------
# Finished episode: 280 Reward: 1286.3356 total_loss = 6.7708 = -0.0499 + 0.5 * 13.6417 + 0.01 * -0.0154
# -----------------
# Finished episode: 281 Reward: 1961.2077 total_loss = 7.6805 = 0.0387 + 0.5 * 15.2838 + 0.01 * -0.0145
# -----------------
# Finished episode: 282 Reward: 1314.2409 total_loss = 6.8657 = 0.0513 + 0.5 * 13.6291 + 0.01 * -0.0148
# -----------------
# Finished episode: 283 Reward: 1251.0070 total_loss = 4.5763 = -0.0483 + 0.5 * 9.2494 + 0.01 * -0.0165
# -----------------
# Finished episode: 284 Reward: 1944.9493 total_loss = 7.1432 = -0.0631 + 0.5 * 14.4131 + 0.01 * -0.0161
# -----------------
# Finished episode: 285 Reward: 2083.6028 total_loss = 7.9926 = -0.0289 + 0.5 * 16.0433 + 0.01 * -0.0161
# -----------------
# Finished episode: 286 Reward: 1666.3185 total_loss = 4.5308 = -0.0904 + 0.5 * 9.2426 + 0.01 * -0.0162
# -----------------
# Finished episode: 287 Reward: 1386.1909 total_loss = 3.4172 = 0.0078 + 0.5 * 6.8190 + 0.01 * -0.0166
# -----------------
# Finished episode: 288 Reward: 1918.5938 total_loss = 8.7893 = -0.0550 + 0.5 * 17.6889 + 0.01 * -0.0172
# -----------------
# Finished episode: 289 Reward: 1277.0631 total_loss = 4.3804 = -0.1382 + 0.5 * 9.0375 + 0.01 * -0.0173
# -----------------
# Finished episode: 290 Reward: 2218.0672 total_loss = 8.9590 = -0.0298 + 0.5 * 17.9780 + 0.01 * -0.0162
# -----------------
# Finished episode: 291 Reward: 2284.7230 total_loss = 7.2787 = -0.1096 + 0.5 * 14.7770 + 0.01 * -0.0174
# -----------------
# Finished episode: 292 Reward: 1701.7027 total_loss = 8.0255 = -0.0396 + 0.5 * 16.1305 + 0.01 * -0.0164
# -----------------
# Finished episode: 293 Reward: 2142.5724 total_loss = 10.6746 = -0.1048 + 0.5 * 21.5590 + 0.01 * -0.0157
# -----------------
# Finished episode: 294 Reward: 2024.4171 total_loss = 8.1203 = -0.0255 + 0.5 * 16.2918 + 0.01 * -0.0148
# -----------------
# Finished episode: 295 Reward: 1885.9714 total_loss = 8.0561 = -0.0879 + 0.5 * 16.2884 + 0.01 * -0.0164
# -----------------
# Finished episode: 296 Reward: 2480.7623 total_loss = 9.9402 = -0.1289 + 0.5 * 20.1385 + 0.01 * -0.0156
# -----------------
# Finished episode: 297 Reward: 2077.0693 total_loss = 7.6862 = -0.0163 + 0.5 * 15.4053 + 0.01 * -0.0162
# -----------------
# Finished episode: 298 Reward: 1442.8611 total_loss = 3.4450 = -0.0499 + 0.5 * 6.9900 + 0.01 * -0.0156
# -----------------
# Finished episode: 299 Reward: 1379.4011 total_loss = 8.0326 = 0.0225 + 0.5 * 16.0204 + 0.01 * -0.0150
# -----------------
# Finished episode: 300 Reward: 1709.1395 total_loss = 6.5577 = -0.0593 + 0.5 * 13.2343 + 0.01 * -0.0159
# -----------------
# Finished episode: 301 Reward: 2289.0682 total_loss = 9.7974 = 0.0526 + 0.5 * 19.4899 + 0.01 * -0.0157
# -----------------
# Finished episode: 302 Reward: 2468.3066 total_loss = 8.7466 = -0.1426 + 0.5 * 17.7787 + 0.01 * -0.0145
# -----------------
# Finished episode: 303 Reward: 1865.0038 total_loss = 4.5967 = -0.0711 + 0.5 * 9.3361 + 0.01 * -0.0164
# -----------------
# Finished episode: 304 Reward: 1690.7814 total_loss = 4.8878 = 0.0348 + 0.5 * 9.7064 + 0.01 * -0.0199
# -----------------
# Finished episode: 305 Reward: 2049.5266 total_loss = 6.4147 = -0.0192 + 0.5 * 12.8682 + 0.01 * -0.0203
# -----------------
# Finished episode: 306 Reward: 2652.9190 total_loss = 9.4591 = -0.0773 + 0.5 * 19.0732 + 0.01 * -0.0168
# -----------------
# Finished episode: 307 Reward: 2387.0953 total_loss = 7.6791 = 0.0459 + 0.5 * 15.2668 + 0.01 * -0.0190
# -----------------
# Finished episode: 308 Reward: 1742.3012 total_loss = 9.5517 = 0.0373 + 0.5 * 19.0291 + 0.01 * -0.0153
# -----------------
# Finished episode: 309 Reward: 1734.4322 total_loss = 7.1666 = -0.1198 + 0.5 * 14.5731 + 0.01 * -0.0185
# -----------------
# Finished episode: 310 Reward: 1315.9345 total_loss = 5.8758 = -0.0963 + 0.5 * 11.9445 + 0.01 * -0.0173
# -----------------
# Finished episode: 311 Reward: 2004.6011 total_loss = 9.4987 = -0.0284 + 0.5 * 19.0546 + 0.01 * -0.0185
# -----------------
# Finished episode: 312 Reward: 1930.8282 total_loss = 5.5989 = -0.0145 + 0.5 * 11.2271 + 0.01 * -0.0166
# -----------------
# Finished episode: 313 Reward: 1673.8741 total_loss = 7.1790 = -0.0366 + 0.5 * 14.4317 + 0.01 * -0.0188
# -----------------
# Finished episode: 314 Reward: 1805.6850 total_loss = 4.7218 = -0.0702 + 0.5 * 9.5844 + 0.01 * -0.0188
# -----------------
# Finished episode: 315 Reward: 1968.1995 total_loss = 8.1706 = -0.0278 + 0.5 * 16.3972 + 0.01 * -0.0183
# -----------------
# Finished episode: 316 Reward: 1799.7175 total_loss = 8.0552 = -0.0686 + 0.5 * 16.2479 + 0.01 * -0.0201
# -----------------
# Finished episode: 317 Reward: 1925.5436 total_loss = 6.5861 = -0.1127 + 0.5 * 13.3980 + 0.01 * -0.0192
# -----------------
# Finished episode: 318 Reward: 2318.6705 total_loss = 9.3142 = -0.1313 + 0.5 * 18.8914 + 0.01 * -0.0160
# -----------------
# Finished episode: 319 Reward: 1551.3144 total_loss = 3.6731 = -0.0407 + 0.5 * 7.4280 + 0.01 * -0.0186
# -----------------
# Finished episode: 320 Reward: 1015.9391 total_loss = 4.1075 = 0.0065 + 0.5 * 8.2025 + 0.01 * -0.0187
# -----------------
# Finished episode: 321 Reward: 1677.3628 total_loss = 9.1929 = 0.0181 + 0.5 * 18.3500 + 0.01 * -0.0168
# -----------------
# Finished episode: 322 Reward: 1491.9491 total_loss = 4.4013 = -0.0889 + 0.5 * 8.9808 + 0.01 * -0.0184
# -----------------
# Finished episode: 323 Reward: 2077.0757 total_loss = 10.1691 = -0.0411 + 0.5 * 20.4207 + 0.01 * -0.0198
# -----------------
# Finished episode: 324 Reward: 1634.6186 total_loss = 5.2793 = -0.0942 + 0.5 * 10.7473 + 0.01 * -0.0191
# -----------------
# Finished episode: 325 Reward: 1795.3638 total_loss = 8.7224 = 0.0086 + 0.5 * 17.4278 + 0.01 * -0.0185
# -----------------
# Finished episode: 326 Reward: 1810.9977 total_loss = 4.0586 = 0.0137 + 0.5 * 8.0901 + 0.01 * -0.0177
# -----------------
# Finished episode: 327 Reward: 2018.0089 total_loss = 7.8554 = -0.0818 + 0.5 * 15.8747 + 0.01 * -0.0190
# -----------------
# Finished episode: 328 Reward: 1949.4590 total_loss = 10.7778 = -0.0087 + 0.5 * 21.5735 + 0.01 * -0.0192
# -----------------
# Finished episode: 329 Reward: 1563.7212 total_loss = 5.7065 = 0.0417 + 0.5 * 11.3300 + 0.01 * -0.0194
# -----------------
# Finished episode: 330 Reward: 1859.8303 total_loss = 7.4472 = -0.0079 + 0.5 * 14.9107 + 0.01 * -0.0195
# -----------------
# Finished episode: 331 Reward: 2065.6408 total_loss = 10.7877 = 0.0464 + 0.5 * 21.4829 + 0.01 * -0.0219
# -----------------
# Finished episode: 332 Reward: 1974.8757 total_loss = 7.4465 = -0.0098 + 0.5 * 14.9129 + 0.01 * -0.0209
# -----------------
# Finished episode: 333 Reward: 2483.4825 total_loss = 9.0877 = -0.0266 + 0.5 * 18.2291 + 0.01 * -0.0215
# -----------------
# Finished episode: 334 Reward: 1323.6605 total_loss = 6.7056 = -0.0302 + 0.5 * 13.4719 + 0.01 * -0.0205
# -----------------
# Finished episode: 335 Reward: 1697.2939 total_loss = 5.4892 = -0.1196 + 0.5 * 11.2180 + 0.01 * -0.0206
# -----------------
# Finished episode: 336 Reward: 1744.5087 total_loss = 8.6378 = 0.0016 + 0.5 * 17.2728 + 0.01 * -0.0198
# -----------------
# Finished episode: 337 Reward: 1998.6833 total_loss = 10.6812 = -0.0821 + 0.5 * 21.5270 + 0.01 * -0.0204
# -----------------
# Finished episode: 338 Reward: 1853.5379 total_loss = 4.1198 = -0.0304 + 0.5 * 8.3007 + 0.01 * -0.0166
# -----------------
# Finished episode: 339 Reward: 1392.2647 total_loss = 6.3366 = -0.0346 + 0.5 * 12.7429 + 0.01 * -0.0199
# -----------------
# Finished episode: 340 Reward: 2307.9545 total_loss = 8.4766 = -0.0353 + 0.5 * 17.0243 + 0.01 * -0.0201
# -----------------
# Finished episode: 341 Reward: 2486.8639 total_loss = 11.6353 = 0.0002 + 0.5 * 23.2707 + 0.01 * -0.0209
# -----------------
# Finished episode: 342 Reward: 1380.8722 total_loss = 6.3613 = -0.0692 + 0.5 * 12.8614 + 0.01 * -0.0166
# -----------------
# Finished episode: 343 Reward: 1698.2294 total_loss = 7.2295 = -0.0622 + 0.5 * 14.5839 + 0.01 * -0.0217
# -----------------
# Finished episode: 344 Reward: 1909.3269 total_loss = 10.2869 = 0.0398 + 0.5 * 20.4946 + 0.01 * -0.0200
# -----------------
# Finished episode: 345 Reward: 2469.8838 total_loss = 7.6871 = -0.0503 + 0.5 * 15.4752 + 0.01 * -0.0203
# -----------------
# Finished episode: 346 Reward: 2780.4808 total_loss = 12.2852 = 0.0015 + 0.5 * 24.5679 + 0.01 * -0.0206
# -----------------
# Finished episode: 347 Reward: 2105.2082 total_loss = 10.2216 = -0.0289 + 0.5 * 20.5014 + 0.01 * -0.0212
# -----------------
# Finished episode: 348 Reward: 1864.6708 total_loss = 8.5517 = -0.0726 + 0.5 * 17.2489 + 0.01 * -0.0193
# -----------------
# Finished episode: 349 Reward: 1649.3079 total_loss = 7.7001 = 0.0081 + 0.5 * 15.3845 + 0.01 * -0.0200
# -----------------
# Finished episode: 350 Reward: 1458.4600 total_loss = 4.5688 = -0.0566 + 0.5 * 9.2513 + 0.01 * -0.0202
# -----------------
# Finished episode: 351 Reward: 2057.5989 total_loss = 7.2031 = 0.0128 + 0.5 * 14.3810 + 0.01 * -0.0214
# -----------------
# Finished episode: 352 Reward: 1604.2064 total_loss = 4.1553 = -0.0082 + 0.5 * 8.3273 + 0.01 * -0.0199
# -----------------
# Finished episode: 353 Reward: 1888.4711 total_loss = 6.6664 = -0.0702 + 0.5 * 13.4735 + 0.01 * -0.0214
# -----------------
# Finished episode: 354 Reward: 2311.3001 total_loss = 9.9796 = -0.0268 + 0.5 * 20.0132 + 0.01 * -0.0221
# -----------------
# Finished episode: 355 Reward: 2356.0590 total_loss = 8.7212 = -0.0027 + 0.5 * 17.4483 + 0.01 * -0.0198
# -----------------
# Finished episode: 356 Reward: 1326.9080 total_loss = 8.4521 = 0.0079 + 0.5 * 16.8888 + 0.01 * -0.0230
# -----------------
# Finished episode: 357 Reward: 1506.9991 total_loss = 2.7480 = -0.0108 + 0.5 * 5.5181 + 0.01 * -0.0206
# -----------------
# Finished episode: 358 Reward: 2781.4274 total_loss = 7.5857 = 0.0052 + 0.5 * 15.1613 + 0.01 * -0.0204
# -----------------
# Finished episode: 359 Reward: 1633.2469 total_loss = 9.9607 = -0.0462 + 0.5 * 20.0141 + 0.01 * -0.0226
# -----------------
# Finished episode: 360 Reward: 2126.0154 total_loss = 9.6509 = -0.0185 + 0.5 * 19.3391 + 0.01 * -0.0225
# -----------------
# Finished episode: 361 Reward: 2404.1796 total_loss = 5.9001 = -0.0601 + 0.5 * 11.9209 + 0.01 * -0.0239
# -----------------
# Finished episode: 362 Reward: 2092.4593 total_loss = 4.5856 = -0.0795 + 0.5 * 9.3306 + 0.01 * -0.0201
# -----------------
# Finished episode: 363 Reward: 2574.1443 total_loss = 11.1797 = -0.0129 + 0.5 * 22.3856 + 0.01 * -0.0229
# -----------------
# Finished episode: 364 Reward: 2249.9254 total_loss = 10.3336 = -0.0194 + 0.5 * 20.7064 + 0.01 * -0.0234
# -----------------
# Finished episode: 365 Reward: 1401.4381 total_loss = 9.0738 = -0.0534 + 0.5 * 18.2549 + 0.01 * -0.0242
# -----------------
# Finished episode: 366 Reward: 1409.9541 total_loss = 8.3278 = -0.0969 + 0.5 * 16.8499 + 0.01 * -0.0250
# -----------------
# Finished episode: 367 Reward: 1966.9598 total_loss = 9.6875 = -0.0316 + 0.5 * 19.4386 + 0.01 * -0.0211
# -----------------
# Finished episode: 368 Reward: 1902.6080 total_loss = 7.0765 = 0.0005 + 0.5 * 14.1524 + 0.01 * -0.0219
# -----------------
# Finished episode: 369 Reward: 1725.3724 total_loss = 5.1311 = 0.0018 + 0.5 * 10.2590 + 0.01 * -0.0215
# -----------------
# Finished episode: 370 Reward: 1721.1939 total_loss = 10.7754 = -0.0285 + 0.5 * 21.6084 + 0.01 * -0.0243
# -----------------
# Finished episode: 371 Reward: 2646.6436 total_loss = 8.0686 = 0.0162 + 0.5 * 16.1052 + 0.01 * -0.0221
# -----------------
# Finished episode: 372 Reward: 2650.5098 total_loss = 8.2626 = -0.0037 + 0.5 * 16.5331 + 0.01 * -0.0236
# -----------------
# Finished episode: 373 Reward: 1789.7939 total_loss = 5.7516 = -0.1475 + 0.5 * 11.7987 + 0.01 * -0.0224
# -----------------
# Finished episode: 374 Reward: 2477.8978 total_loss = 8.4982 = -0.0226 + 0.5 * 17.0419 + 0.01 * -0.0209
# -----------------
# Finished episode: 375 Reward: 2605.3652 total_loss = 8.5924 = -0.0170 + 0.5 * 17.2193 + 0.01 * -0.0213
# -----------------
# Finished episode: 376 Reward: 1922.3493 total_loss = 5.7447 = -0.0521 + 0.5 * 11.5940 + 0.01 * -0.0206
# -----------------
# Finished episode: 377 Reward: 2432.0210 total_loss = 10.6347 = 0.0391 + 0.5 * 21.1915 + 0.01 * -0.0215
# -----------------
# Finished episode: 378 Reward: 2409.1738 total_loss = 9.3807 = -0.0673 + 0.5 * 18.8964 + 0.01 * -0.0205
# -----------------
# Finished episode: 379 Reward: 1803.1496 total_loss = 5.4436 = -0.1176 + 0.5 * 11.1227 + 0.01 * -0.0219
# -----------------
# Finished episode: 380 Reward: 1679.2202 total_loss = 7.4374 = -0.0557 + 0.5 * 14.9867 + 0.01 * -0.0220
# -----------------
# Finished episode: 381 Reward: 1877.0118 total_loss = 10.1007 = -0.0237 + 0.5 * 20.2492 + 0.01 * -0.0216
# -----------------
# Finished episode: 382 Reward: 2393.1444 total_loss = 10.0528 = -0.0308 + 0.5 * 20.1676 + 0.01 * -0.0237
# -----------------
# Finished episode: 383 Reward: 2382.0501 total_loss = 9.0084 = 0.0058 + 0.5 * 18.0057 + 0.01 * -0.0230
# -----------------
# Finished episode: 384 Reward: 2098.2901 total_loss = 9.8486 = -0.0502 + 0.5 * 19.7979 + 0.01 * -0.0204
# -----------------
# Finished episode: 385 Reward: 2870.1864 total_loss = 12.1799 = -0.0026 + 0.5 * 24.3654 + 0.01 * -0.0222
# -----------------
# Finished episode: 386 Reward: 2146.9934 total_loss = 6.0569 = -0.0084 + 0.5 * 12.1309 + 0.01 * -0.0206
# -----------------
# Finished episode: 387 Reward: 1824.9642 total_loss = 8.8076 = -0.0203 + 0.5 * 17.6562 + 0.01 * -0.0216
# -----------------
# Finished episode: 388 Reward: 1728.6878 total_loss = 8.0337 = 0.1092 + 0.5 * 15.8495 + 0.01 * -0.0224
# -----------------
# Finished episode: 389 Reward: 2077.4946 total_loss = 8.0257 = -0.0219 + 0.5 * 16.0957 + 0.01 * -0.0213
# -----------------
# Finished episode: 390 Reward: 2140.3922 total_loss = 7.2598 = -0.1108 + 0.5 * 14.7416 + 0.01 * -0.0228
# -----------------
# Finished episode: 391 Reward: 2535.0264 total_loss = 9.0715 = -0.0162 + 0.5 * 18.1758 + 0.01 * -0.0206
# -----------------
# Finished episode: 392 Reward: 1918.8916 total_loss = 6.7917 = -0.0762 + 0.5 * 13.7362 + 0.01 * -0.0207
# -----------------
# Finished episode: 393 Reward: 1731.9552 total_loss = 7.6358 = -0.0039 + 0.5 * 15.2799 + 0.01 * -0.0183
# -----------------
# Finished episode: 394 Reward: 1640.9375 total_loss = 7.8293 = 0.0425 + 0.5 * 15.5741 + 0.01 * -0.0228
# -----------------
# Finished episode: 395 Reward: 1941.4952 total_loss = 5.4349 = -0.0321 + 0.5 * 10.9345 + 0.01 * -0.0211
# -----------------
# Finished episode: 396 Reward: 2044.9110 total_loss = 9.1369 = -0.0797 + 0.5 * 18.4336 + 0.01 * -0.0217
# -----------------
# Finished episode: 397 Reward: 1761.5896 total_loss = 10.5783 = -0.1063 + 0.5 * 21.3696 + 0.01 * -0.0199
# -----------------
# Finished episode: 398 Reward: 1779.7336 total_loss = 12.3192 = 0.0287 + 0.5 * 24.5814 + 0.01 * -0.0212
# -----------------
# Finished episode: 399 Reward: 2060.4090 total_loss = 12.2334 = -0.0177 + 0.5 * 24.5026 + 0.01 * -0.0212
# -----------------
# Finished episode: 400 Reward: 1504.9911 total_loss = 7.7573 = -0.0011 + 0.5 * 15.5174 + 0.01 * -0.0228
# ...
# Finished episode: 476 Reward: 96.9186 total_loss = 0.2003 = 0.0480 + 0.5 * 0.3104 + 0.01 * -0.2872
# -----------------
# Finished episode: 477 Reward: 93.6969 total_loss = 0.0798 = -0.0553 + 0.5 * 0.2757 + 0.01 * -0.2836
# -----------------
# Finished episode: 478 Reward: 93.8569 total_loss = 0.1537 = -0.0049 + 0.5 * 0.3228 + 0.01 * -0.2795
# -----------------
# Finished episode: 479 Reward: 93.4594 total_loss = 0.0580 = -0.0930 + 0.5 * 0.3078 + 0.01 * -0.2903
# -----------------
# Finished episode: 480 Reward: 93.8289 total_loss = 0.2124 = 0.0261 + 0.5 * 0.3782 + 0.01 * -0.2829
# -----------------
# Finished episode: 481 Reward: 95.0332 total_loss = -0.0081 = -0.1322 + 0.5 * 0.2538 + 0.01 * -0.2837
# -----------------
# Finished episode: 482 Reward: 92.1976 total_loss = 0.2433 = 0.0479 + 0.5 * 0.3965 + 0.01 * -0.2850
# -----------------
# Finished episode: 483 Reward: 94.9778 total_loss = 0.0817 = -0.0406 + 0.5 * 0.2504 + 0.01 * -0.2895
# -----------------
# Finished episode: 484 Reward: 96.1710 total_loss = 0.0156 = -0.0897 + 0.5 * 0.2163 + 0.01 * -0.2872
# -----------------
# Finished episode: 485 Reward: 97.9101 total_loss = 0.2047 = 0.0253 + 0.5 * 0.3645 + 0.01 * -0.2815
# -----------------
# Finished episode: 486 Reward: 95.3306 total_loss = 0.1057 = -0.0744 + 0.5 * 0.3660 + 0.01 * -0.2892
# -----------------
# Finished episode: 487 Reward: 95.3519 total_loss = 0.0701 = -0.0981 + 0.5 * 0.3421 + 0.01 * -0.2775
# -----------------
# Finished episode: 488 Reward: 92.8411 total_loss = 0.1371 = -0.0575 + 0.5 * 0.3949 + 0.01 * -0.2814
# -----------------
# Finished episode: 489 Reward: 93.0586 total_loss = 0.1123 = -0.0429 + 0.5 * 0.3161 + 0.01 * -0.2792
# -----------------
# Finished episode: 490 Reward: 93.1348 total_loss = 0.2040 = 0.0126 + 0.5 * 0.3885 + 0.01 * -0.2850
# -----------------
# Finished episode: 491 Reward: 95.5938 total_loss = 0.2333 = -0.0053 + 0.5 * 0.4829 + 0.01 * -0.2835
# -----------------
# Finished episode: 492 Reward: 97.9883 total_loss = 0.2025 = -0.0269 + 0.5 * 0.4646 + 0.01 * -0.2925
# -----------------
# Finished episode: 493 Reward: 96.7185 total_loss = 0.1870 = 0.0136 + 0.5 * 0.3525 + 0.01 * -0.2840
# -----------------
# Finished episode: 494 Reward: 96.6623 total_loss = 0.1579 = -0.0349 + 0.5 * 0.3912 + 0.01 * -0.2838
# -----------------
# Finished episode: 495 Reward: 94.8060 total_loss = 0.2140 = 0.0409 + 0.5 * 0.3520 + 0.01 * -0.2938
# -----------------
# Finished episode: 496 Reward: 97.1504 total_loss = 0.1784 = 0.0028 + 0.5 * 0.3568 + 0.01 * -0.2824
# -----------------
# Finished episode: 497 Reward: 96.7145 total_loss = 0.0189 = -0.1283 + 0.5 * 0.3003 + 0.01 * -0.2911
# -----------------
# Finished episode: 498 Reward: 90.3209 total_loss = 0.2617 = 0.0621 + 0.5 * 0.4051 + 0.01 * -0.2887
# -----------------
# Finished episode: 499 Reward: 96.9001 total_loss = 0.0946 = -0.0497 + 0.5 * 0.2943 + 0.01 * -0.2877
# -----------------
# Finished episode: 500 Reward: 98.1384 total_loss = 0.2370 = 0.0295 + 0.5 * 0.4206 + 0.01 * -0.2787
# -----------------
# Finished episode: 501 Reward: 94.4540 total_loss = 0.2337 = 0.0814 + 0.5 * 0.3102 + 0.01 * -0.2785
# -----------------
# Finished episode: 502 Reward: 93.1722 total_loss = 0.2284 = 0.0044 + 0.5 * 0.4537 + 0.01 * -0.2840
# -----------------
# Finished episode: 503 Reward: 94.2575 total_loss = 0.2364 = 0.0292 + 0.5 * 0.4199 + 0.01 * -0.2799
# -----------------
# Finished episode: 504 Reward: 97.9127 total_loss = 0.2721 = 0.0696 + 0.5 * 0.4104 + 0.01 * -0.2744
# -----------------
# Finished episode: 505 Reward: 96.6343 total_loss = 0.1921 = -0.0113 + 0.5 * 0.4126 + 0.01 * -0.2941
# -----------------
# Finished episode: 506 Reward: 98.5271 total_loss = 0.2497 = 0.0548 + 0.5 * 0.3954 + 0.01 * -0.2869
# -----------------
# Finished episode: 507 Reward: 96.6464 total_loss = 0.1563 = -0.0262 + 0.5 * 0.3706 + 0.01 * -0.2808
# -----------------
# Finished episode: 508 Reward: 99.6052 total_loss = 0.1946 = 0.0698 + 0.5 * 0.2554 + 0.01 * -0.2880
# -----------------
# Finished episode: 509 Reward: 99.6336 total_loss = 0.1414 = -0.0016 + 0.5 * 0.2917 + 0.01 * -0.2900
# -----------------
# Finished episode: 510 Reward: 98.0235 total_loss = 0.1553 = -0.0049 + 0.5 * 0.3261 + 0.01 * -0.2880
# -----------------
# Finished episode: 511 Reward: 98.7185 total_loss = 0.0938 = -0.0515 + 0.5 * 0.2964 + 0.01 * -0.2859
# -----------------
# Finished episode: 512 Reward: 97.8348 total_loss = 0.1640 = 0.0215 + 0.5 * 0.2908 + 0.01 * -0.2897
# -----------------
# Finished episode: 513 Reward: 95.4101 total_loss = 0.1278 = -0.0121 + 0.5 * 0.2856 + 0.01 * -0.2847
# -----------------
# Finished episode: 514 Reward: 97.7855 total_loss = 0.0103 = -0.1007 + 0.5 * 0.2277 + 0.01 * -0.2888
# -----------------
# Finished episode: 515 Reward: 96.0605 total_loss = 0.1542 = -0.0024 + 0.5 * 0.3186 + 0.01 * -0.2706
# -----------------
# Finished episode: 516 Reward: 99.4905 total_loss = 0.2630 = 0.0589 + 0.5 * 0.4140 + 0.01 * -0.2827
# -----------------
# Finished episode: 517 Reward: 100.8987 total_loss = 0.2736 = 0.0824 + 0.5 * 0.3879 + 0.01 * -0.2813
# -----------------
# Finished episode: 518 Reward: 98.6289 total_loss = 0.1978 = 0.0537 + 0.5 * 0.2939 + 0.01 * -0.2819
# -----------------
# Finished episode: 519 Reward: 95.8830 total_loss = 0.1095 = -0.0275 + 0.5 * 0.2798 + 0.01 * -0.2904
# -----------------
# Finished episode: 520 Reward: 93.6820 total_loss = 0.0469 = -0.1225 + 0.5 * 0.3444 + 0.01 * -0.2790
# -----------------
# Finished episode: 521 Reward: 95.8622 total_loss = 0.1426 = 0.0037 + 0.5 * 0.2835 + 0.01 * -0.2826
# -----------------
# Finished episode: 522 Reward: 94.4127 total_loss = 0.1439 = -0.0109 + 0.5 * 0.3153 + 0.01 * -0.2871
# -----------------
# Finished episode: 523 Reward: 93.9961 total_loss = 0.0791 = -0.0837 + 0.5 * 0.3315 + 0.01 * -0.2926
# -----------------
# Finished episode: 524 Reward: 97.5233 total_loss = 0.1347 = -0.0344 + 0.5 * 0.3438 + 0.01 * -0.2760
# -----------------
# Finished episode: 525 Reward: 96.6239 total_loss = 0.0173 = -0.1144 + 0.5 * 0.2690 + 0.01 * -0.2783
# -----------------
# Finished episode: 526 Reward: 97.3341 total_loss = 0.2931 = 0.0723 + 0.5 * 0.4474 + 0.01 * -0.2850
# -----------------
# Finished episode: 527 Reward: 96.1901 total_loss = 0.0972 = -0.0191 + 0.5 * 0.2381 + 0.01 * -0.2737
# -----------------
# Finished episode: 528 Reward: 93.6903 total_loss = 0.1450 = 0.0265 + 0.5 * 0.2428 + 0.01 * -0.2790
# -----------------
# Finished episode: 529 Reward: 93.0871 total_loss = 0.1579 = 0.0264 + 0.5 * 0.2687 + 0.01 * -0.2825
# -----------------
# Finished episode: 530 Reward: 93.4451 total_loss = 0.1175 = -0.0518 + 0.5 * 0.3445 + 0.01 * -0.2892
# -----------------
# Finished episode: 531 Reward: 94.6301 total_loss = 0.0929 = -0.0206 + 0.5 * 0.2325 + 0.01 * -0.2743
# -----------------
# Finished episode: 532 Reward: 92.9190 total_loss = 0.2277 = 0.0071 + 0.5 * 0.4467 + 0.01 * -0.2774
# -----------------
# Finished episode: 533 Reward: 94.0152 total_loss = 0.2386 = 0.0091 + 0.5 * 0.4645 + 0.01 * -0.2795
# -----------------
# Finished episode: 534 Reward: 97.8897 total_loss = 0.1191 = -0.0301 + 0.5 * 0.3040 + 0.01 * -0.2784
# -----------------
# Finished episode: 535 Reward: 98.4194 total_loss = 0.2415 = 0.0659 + 0.5 * 0.3564 + 0.01 * -0.2644
# -----------------
# Finished episode: 536 Reward: 97.0867 total_loss = 0.2740 = 0.1081 + 0.5 * 0.3372 + 0.01 * -0.2749
# -----------------
# Finished episode: 537 Reward: 93.2482 total_loss = 0.1677 = 0.0239 + 0.5 * 0.2931 + 0.01 * -0.2749
# -----------------
# Finished episode: 538 Reward: 99.3156 total_loss = 0.0502 = -0.0630 + 0.5 * 0.2321 + 0.01 * -0.2793
# -----------------
# Finished episode: 539 Reward: 97.3714 total_loss = 0.1607 = 0.0113 + 0.5 * 0.3042 + 0.01 * -0.2725
# -----------------
# Finished episode: 540 Reward: 95.3198 total_loss = 0.0911 = -0.0287 + 0.5 * 0.2453 + 0.01 * -0.2804
# -----------------
# Finished episode: 541 Reward: 97.3964 total_loss = 0.2265 = 0.0746 + 0.5 * 0.3094 + 0.01 * -0.2774
# -----------------
# Finished episode: 542 Reward: 91.8257 total_loss = 0.2502 = 0.0806 + 0.5 * 0.3448 + 0.01 * -0.2779
# -----------------
# Finished episode: 543 Reward: 93.5327 total_loss = 0.1813 = -0.0061 + 0.5 * 0.3805 + 0.01 * -0.2863
# -----------------
# Finished episode: 544 Reward: 98.5825 total_loss = 0.0909 = -0.0720 + 0.5 * 0.3313 + 0.01 * -0.2786
# -----------------
# Finished episode: 545 Reward: 97.9501 total_loss = 0.1910 = -0.0505 + 0.5 * 0.4882 + 0.01 * -0.2697
# -----------------
# Finished episode: 546 Reward: 94.5785 total_loss = 0.1976 = 0.0328 + 0.5 * 0.3353 + 0.01 * -0.2852
# -----------------
# Finished episode: 547 Reward: 94.0259 total_loss = 0.1837 = -0.0051 + 0.5 * 0.3834 + 0.01 * -0.2874
# -----------------
# Finished episode: 548 Reward: 99.4304 total_loss = 0.1063 = -0.0429 + 0.5 * 0.3039 + 0.01 * -0.2774
# -----------------
# Finished episode: 549 Reward: 99.3409 total_loss = 0.1206 = -0.0261 + 0.5 * 0.2989 + 0.01 * -0.2820
# -----------------
# Finished episode: 550 Reward: 100.8898 total_loss = 0.1508 = 0.0047 + 0.5 * 0.2978 + 0.01 * -0.2762
# -----------------
# Finished episode: 551 Reward: 99.4366 total_loss = 0.0775 = -0.0466 + 0.5 * 0.2539 + 0.01 * -0.2858
# -----------------
# Finished episode: 552 Reward: 100.7971 total_loss = 0.1301 = -0.0333 + 0.5 * 0.3323 + 0.01 * -0.2766
# -----------------
# Finished episode: 553 Reward: 101.3391 total_loss = 0.1530 = -0.0058 + 0.5 * 0.3230 + 0.01 * -0.2787
# -----------------
# Finished episode: 554 Reward: 99.1572 total_loss = 0.1860 = 0.0243 + 0.5 * 0.3290 + 0.01 * -0.2758
# -----------------
# Finished episode: 555 Reward: 99.0465 total_loss = 0.0786 = -0.0572 + 0.5 * 0.2770 + 0.01 * -0.2739
# -----------------
# Finished episode: 556 Reward: 99.1878 total_loss = 0.1860 = 0.0475 + 0.5 * 0.2825 + 0.01 * -0.2777
# -----------------
# Finished episode: 557 Reward: 98.2758 total_loss = 0.2545 = 0.0424 + 0.5 * 0.4297 + 0.01 * -0.2816
# -----------------
# Finished episode: 558 Reward: 98.6806 total_loss = 0.1825 = 0.0026 + 0.5 * 0.3655 + 0.01 * -0.2831
# -----------------
# Finished episode: 559 Reward: 98.2827 total_loss = 0.2137 = 0.0737 + 0.5 * 0.2856 + 0.01 * -0.2747
# -----------------
# Finished episode: 560 Reward: 97.5207 total_loss = 0.1714 = -0.0118 + 0.5 * 0.3719 + 0.01 * -0.2737
# -----------------
# Finished episode: 561 Reward: 97.8494 total_loss = 0.0501 = -0.0626 + 0.5 * 0.2310 + 0.01 * -0.2867
# -----------------
# Finished episode: 562 Reward: 97.7264 total_loss = 0.1052 = 0.0115 + 0.5 * 0.1931 + 0.01 * -0.2835
# -----------------
# Finished episode: 563 Reward: 96.3448 total_loss = 0.1847 = 0.0440 + 0.5 * 0.2869 + 0.01 * -0.2699
# -----------------
# Finished episode: 564 Reward: 95.4064 total_loss = 0.0827 = -0.0213 + 0.5 * 0.2137 + 0.01 * -0.2839
# -----------------
# Finished episode: 565 Reward: 97.2773 total_loss = 0.0970 = -0.0312 + 0.5 * 0.2618 + 0.01 * -0.2713
# -----------------
# Finished episode: 566 Reward: 99.1988 total_loss = 0.2128 = -0.0212 + 0.5 * 0.4736 + 0.01 * -0.2764
# -----------------
# Finished episode: 567 Reward: 98.7310 total_loss = 0.1253 = -0.0040 + 0.5 * 0.2640 + 0.01 * -0.2659
# -----------------
# Finished episode: 568 Reward: 97.1020 total_loss = 0.2523 = 0.0437 + 0.5 * 0.4229 + 0.01 * -0.2785
# -----------------
# Finished episode: 569 Reward: 99.0315 total_loss = 0.0275 = -0.0833 + 0.5 * 0.2269 + 0.01 * -0.2664
# -----------------
# Finished episode: 570 Reward: 98.4052 total_loss = 0.1277 = -0.0508 + 0.5 * 0.3625 + 0.01 * -0.2759
# -----------------
# Finished episode: 571 Reward: 97.1700 total_loss = 0.2450 = 0.0804 + 0.5 * 0.3347 + 0.01 * -0.2839
# -----------------
# Finished episode: 572 Reward: 97.9981 total_loss = 0.2367 = 0.0525 + 0.5 * 0.3738 + 0.01 * -0.2731
# -----------------
# Finished episode: 573 Reward: 99.1325 total_loss = 0.1659 = -0.0021 + 0.5 * 0.3416 + 0.01 * -0.2785
# -----------------
# Finished episode: 574 Reward: 99.6813 total_loss = 0.0424 = -0.0977 + 0.5 * 0.2858 + 0.01 * -0.2808
# -----------------
# Finished episode: 575 Reward: 101.3860 total_loss = 0.0358 = -0.0579 + 0.5 * 0.1928 + 0.01 * -0.2708
# -----------------
# Finished episode: 576 Reward: 101.2876 total_loss = 0.2097 = 0.0132 + 0.5 * 0.3983 + 0.01 * -0.2740
# -----------------
# Finished episode: 577 Reward: 97.4348 total_loss = 0.2238 = 0.0652 + 0.5 * 0.3226 + 0.01 * -0.2637
# -----------------
# Finished episode: 578 Reward: 98.1388 total_loss = 0.1068 = -0.0053 + 0.5 * 0.2298 + 0.01 * -0.2759
# -----------------
# Finished episode: 579 Reward: 97.5156 total_loss = 0.2038 = 0.0560 + 0.5 * 0.3008 + 0.01 * -0.2651
# -----------------
# Finished episode: 580 Reward: 99.7162 total_loss = 0.1068 = -0.0525 + 0.5 * 0.3239 + 0.01 * -0.2704
# -----------------
# Finished episode: 581 Reward: 100.4194 total_loss = 0.2016 = 0.0371 + 0.5 * 0.3343 + 0.01 * -0.2733
# -----------------
# Finished episode: 582 Reward: 97.5548 total_loss = 0.0718 = -0.0567 + 0.5 * 0.2622 + 0.01 * -0.2628
# -----------------
# Finished episode: 583 Reward: 99.0151 total_loss = 0.1885 = 0.0200 + 0.5 * 0.3423 + 0.01 * -0.2721
# -----------------
# Finished episode: 584 Reward: 100.7788 total_loss = 0.1399 = -0.0417 + 0.5 * 0.3687 + 0.01 * -0.2716
# -----------------
# Finished episode: 585 Reward: 98.2615 total_loss = 0.1854 = -0.0161 + 0.5 * 0.4082 + 0.01 * -0.2616
# -----------------
# Finished episode: 586 Reward: 97.2278 total_loss = 0.1457 = -0.0300 + 0.5 * 0.3568 + 0.01 * -0.2715
# -----------------
# Finished episode: 587 Reward: 97.8990 total_loss = 0.1069 = -0.0482 + 0.5 * 0.3154 + 0.01 * -0.2652
# -----------------
# Finished episode: 588 Reward: 98.5061 total_loss = 0.0466 = -0.1042 + 0.5 * 0.3070 + 0.01 * -0.2660
# -----------------
# Finished episode: 589 Reward: 99.8965 total_loss = 0.1333 = -0.0503 + 0.5 * 0.3728 + 0.01 * -0.2817
# -----------------
# Finished episode: 590 Reward: 99.8140 total_loss = 0.2001 = -0.0035 + 0.5 * 0.4128 + 0.01 * -0.2777
# -----------------
# Finished episode: 591 Reward: 99.2721 total_loss = 0.2452 = 0.0471 + 0.5 * 0.4015 + 0.01 * -0.2617
# -----------------
# Finished episode: 592 Reward: 94.8074 total_loss = 0.5499 = 0.2342 + 0.5 * 0.6370 + 0.01 * -0.2789
# -----------------
# Finished episode: 593 Reward: 97.9740 total_loss = 0.2588 = 0.0503 + 0.5 * 0.4225 + 0.01 * -0.2746
# -----------------
# Finished episode: 594 Reward: 96.3618 total_loss = 0.1762 = 0.0126 + 0.5 * 0.3325 + 0.01 * -0.2632
# -----------------
# Finished episode: 595 Reward: 98.4762 total_loss = 0.1842 = 0.0097 + 0.5 * 0.3546 + 0.01 * -0.2745
# -----------------
# Finished episode: 596 Reward: 97.1417 total_loss = 0.1539 = 0.0015 + 0.5 * 0.3105 + 0.01 * -0.2818
# -----------------
# Finished episode: 597 Reward: 100.1146 total_loss = 0.2690 = 0.0500 + 0.5 * 0.4434 + 0.01 * -0.2714
# -----------------
# Finished episode: 598 Reward: 98.3982 total_loss = 0.1638 = 0.0122 + 0.5 * 0.3083 + 0.01 * -0.2603
# -----------------
# Finished episode: 599 Reward: 95.3172 total_loss = 0.2020 = -0.0185 + 0.5 * 0.4462 + 0.01 * -0.2655
# -----------------
# Finished episode: 600 Reward: 99.4383 total_loss = 0.0723 = -0.0702 + 0.5 * 0.2902 + 0.01 * -0.2653
# -----------------
# Finished episode: 601 Reward: 99.1073 total_loss = 0.1463 = -0.0662 + 0.5 * 0.4303 + 0.01 * -0.2699
# -----------------
# Finished episode: 602 Reward: 99.8409 total_loss = 0.1653 = -0.0033 + 0.5 * 0.3425 + 0.01 * -0.2695
# -----------------
# Finished episode: 603 Reward: 97.1895 total_loss = 0.2486 = 0.0073 + 0.5 * 0.4882 + 0.01 * -0.2762
# -----------------
# Finished episode: 604 Reward: 98.1109 total_loss = 0.2854 = 0.0595 + 0.5 * 0.4571 + 0.01 * -0.2716
# -----------------
# Finished episode: 605 Reward: 99.4092 total_loss = 0.1282 = -0.0244 + 0.5 * 0.3105 + 0.01 * -0.2752
# -----------------
# Finished episode: 606 Reward: 98.4004 total_loss = 0.1012 = -0.0440 + 0.5 * 0.2959 + 0.01 * -0.2719
# -----------------
# Finished episode: 607 Reward: 100.0116 total_loss = 0.2626 = 0.0616 + 0.5 * 0.4077 + 0.01 * -0.2825
# -----------------
# Finished episode: 608 Reward: 99.2465 total_loss = 0.0634 = -0.0628 + 0.5 * 0.2578 + 0.01 * -0.2718
# -----------------
# Finished episode: 609 Reward: 97.8122 total_loss = 0.1940 = 0.0090 + 0.5 * 0.3754 + 0.01 * -0.2700
# -----------------
# Finished episode: 610 Reward: 100.4052 total_loss = 0.1934 = 0.0483 + 0.5 * 0.2959 + 0.01 * -0.2862
# -----------------
# Finished episode: 611 Reward: 97.8657 total_loss = 0.2223 = -0.0069 + 0.5 * 0.4640 + 0.01 * -0.2791
# -----------------
